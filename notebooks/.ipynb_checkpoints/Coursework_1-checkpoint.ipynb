# %% [markdown]
# # Coursework 1
#
# This notebook is intended to be used as a starting point for your experiments. The instructions can be found in the instructions file located under spec/coursework1.pdf. The methods provided here are just helper functions. If you want more complex graphs such as side by side comparisons of different experiments you should learn more about matplotlib and implement them. Before each experiment remember to re-initialize neural network weights and reset the data providers so you get a properly initialized experiment. For each experiment try to keep most hyperparameters the same except the one under investigation so you can understand what the effects of each are.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

def train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True, early_stopping=False):
    
    # As well as monitoring the error over training also monitor classification
    # accuracy i.e. proportion of most-probable predicted classes being equal to targets
    data_monitors={'acc': lambda y, t: (y.argmax(-1) == t.argmax(-1)).mean()}

    # Use the created objects to initialise a new Optimiser instance.
    optimiser = Optimiser(
        model, error, learning_rule, train_data, valid_data, data_monitors, notebook=notebook)

    # Run the optimiser for 5 epochs (full passes through the training set)
    # printing statistics every epoch.
    stats, keys, run_time = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval, early_stopping=early_stopping)

    # Plot the change in the validation and training set error over training.
    fig_1 = plt.figure(figsize=(8, 4))
    ax_1 = fig_1.add_subplot(111)
    for k in ['error(train)', 'error(valid)']:
        ax_1.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_1.legend(loc=0)
    ax_1.set_xlabel('Epoch number')

    # Plot the change in the validation and training set accuracy over training.
    fig_2 = plt.figure(figsize=(8, 4))
    ax_2 = fig_2.add_subplot(111)
    for k in ['acc(train)', 'acc(valid)']:
        ax_2.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_2.legend(loc=0)
    ax_2.set_xlabel('Epoch number')
    
    print(optimiser.eval_monitors(test_data, "(test)"))
    return stats, keys, run_time, fig_1, ax_1, fig_2, ax_2

# %%
# The below code will set up the data providers, random number
# generator and logger objects needed for training runs. As
# loading the data from file take a little while you generally
# will probably not want to reload the data providers on
# every training run. If you wish to reset their state you
# should instead use the .reset() method of the data providers.
import numpy as np
import logging
from mlp.data_providers import MNISTDataProvider, EMNISTDataProvider

# Seed a random number generator
seed = 11102019 
rng = np.random.RandomState(seed)
batch_size = 100
# Set up a logger object to print info about the training run to stdout
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.handlers = [logging.StreamHandler()]

# Create data provider objects for the MNIST data set
train_data = EMNISTDataProvider('train', batch_size=batch_size, rng=rng)
valid_data = EMNISTDataProvider('valid', batch_size=batch_size, rng=rng)
test_data = EMNISTDataProvider('test', batch_size=batch_size, rng=rng)
# Out:
# KeysView(<numpy.lib.npyio.NpzFile object at 0x000001CD0A4BA148>)
# KeysView(<numpy.lib.npyio.NpzFile object at 0x000001CD0A878FC8>)
# KeysView(<numpy.lib.npyio.NpzFile object at 0x000001CD0A4144C8>)

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import AdamLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule()

#Remember to use notebook=False when you write a script to be run in a terminal
#_ = train_model_and_plot_stats(model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, RandomReluLayer, ParametricReluLayer, ExponentialLinearUnitLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import AdamLearningRule
from mlp.optimisers import Optimiser

# %% [markdown]
# ## Leaky Relu

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    LeakyReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])
error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule()
#Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

# %% [markdown]
# ## RandomRelu

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    RandomReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    RandomReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])
error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule()
#Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 1: 8.9s to complete
#     error(train)=8.71e-01, acc(train)=7.43e-01, error(valid)=8.89e-01, acc(valid)=7.39e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 2: 6.9s to complete
#     error(train)=7.15e-01, acc(train)=7.80e-01, error(valid)=7.51e-01, acc(valid)=7.68e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 3: 6.6s to complete
#     error(train)=6.13e-01, acc(train)=8.07e-01, error(valid)=6.58e-01, acc(valid)=7.97e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 4: 6.7s to complete
#     error(train)=5.62e-01, acc(train)=8.17e-01, error(valid)=6.19e-01, acc(valid)=8.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 5: 6.5s to complete
#     error(train)=5.16e-01, acc(train)=8.30e-01, error(valid)=5.82e-01, acc(valid)=8.13e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 6: 6.6s to complete
#     error(train)=4.93e-01, acc(train)=8.37e-01, error(valid)=5.75e-01, acc(valid)=8.15e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 7: 6.5s to complete
#     error(train)=4.70e-01, acc(train)=8.44e-01, error(valid)=5.56e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 8: 6.4s to complete
#     error(train)=4.55e-01, acc(train)=8.44e-01, error(valid)=5.50e-01, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 9: 6.7s to complete
#     error(train)=4.41e-01, acc(train)=8.49e-01, error(valid)=5.50e-01, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 10: 6.6s to complete
#     error(train)=4.55e-01, acc(train)=8.44e-01, error(valid)=5.70e-01, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 11: 6.9s to complete
#     error(train)=4.14e-01, acc(train)=8.57e-01, error(valid)=5.37e-01, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 12: 7.0s to complete
#     error(train)=4.03e-01, acc(train)=8.60e-01, error(valid)=5.27e-01, acc(valid)=8.29e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 13: 6.9s to complete
#     error(train)=3.98e-01, acc(train)=8.62e-01, error(valid)=5.34e-01, acc(valid)=8.27e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 14: 7.5s to complete
#     error(train)=4.04e-01, acc(train)=8.58e-01, error(valid)=5.45e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 15: 6.0s to complete
#     error(train)=3.73e-01, acc(train)=8.68e-01, error(valid)=5.21e-01, acc(valid)=8.31e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 16: 6.7s to complete
#     error(train)=3.65e-01, acc(train)=8.71e-01, error(valid)=5.15e-01, acc(valid)=8.33e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 17: 6.6s to complete
#     error(train)=3.74e-01, acc(train)=8.66e-01, error(valid)=5.33e-01, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 18: 7.4s to complete
#     error(train)=3.65e-01, acc(train)=8.69e-01, error(valid)=5.37e-01, acc(valid)=8.29e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 19: 5.9s to complete
#     error(train)=3.74e-01, acc(train)=8.66e-01, error(valid)=5.47e-01, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 20: 7.3s to complete
#     error(train)=3.49e-01, acc(train)=8.73e-01, error(valid)=5.29e-01, acc(valid)=8.31e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 21: 8.7s to complete
#     error(train)=3.52e-01, acc(train)=8.71e-01, error(valid)=5.39e-01, acc(valid)=8.27e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 22: 10.2s to complete
#     error(train)=3.45e-01, acc(train)=8.75e-01, error(valid)=5.30e-01, acc(valid)=8.33e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 23: 6.0s to complete
#     error(train)=3.41e-01, acc(train)=8.75e-01, error(valid)=5.33e-01, acc(valid)=8.33e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 24: 5.4s to complete
#     error(train)=3.40e-01, acc(train)=8.77e-01, error(valid)=5.39e-01, acc(valid)=8.30e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 25: 6.2s to complete
#     error(train)=3.35e-01, acc(train)=8.77e-01, error(valid)=5.32e-01, acc(valid)=8.31e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 26: 6.2s to complete
#     error(train)=3.23e-01, acc(train)=8.81e-01, error(valid)=5.46e-01, acc(valid)=8.33e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 27: 5.6s to complete
#     error(train)=3.29e-01, acc(train)=8.80e-01, error(valid)=5.46e-01, acc(valid)=8.32e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 28: 5.9s to complete
#     error(train)=3.14e-01, acc(train)=8.84e-01, error(valid)=5.39e-01, acc(valid)=8.35e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 29: 7.0s to complete
#     error(train)=3.13e-01, acc(train)=8.84e-01, error(valid)=5.40e-01, acc(valid)=8.34e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 30: 5.9s to complete
#     error(train)=3.28e-01, acc(train)=8.78e-01, error(valid)=5.56e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 31: 6.2s to complete
#     error(train)=3.10e-01, acc(train)=8.84e-01, error(valid)=5.49e-01, acc(valid)=8.31e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 32: 6.0s to complete
#     error(train)=3.05e-01, acc(train)=8.88e-01, error(valid)=5.49e-01, acc(valid)=8.37e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 33: 6.0s to complete
#     error(train)=3.08e-01, acc(train)=8.85e-01, error(valid)=5.54e-01, acc(valid)=8.32e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 34: 6.0s to complete
#     error(train)=2.98e-01, acc(train)=8.89e-01, error(valid)=5.48e-01, acc(valid)=8.38e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 35: 5.3s to complete
#     error(train)=3.04e-01, acc(train)=8.88e-01, error(valid)=5.67e-01, acc(valid)=8.32e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 36: 5.0s to complete
#     error(train)=2.91e-01, acc(train)=8.91e-01, error(valid)=5.57e-01, acc(valid)=8.33e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 37: 5.6s to complete
#     error(train)=2.93e-01, acc(train)=8.90e-01, error(valid)=5.59e-01, acc(valid)=8.34e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 38: 6.1s to complete
#     error(train)=3.02e-01, acc(train)=8.86e-01, error(valid)=5.73e-01, acc(valid)=8.32e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 39: 4.9s to complete
#     error(train)=2.78e-01, acc(train)=8.95e-01, error(valid)=5.57e-01, acc(valid)=8.38e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 40: 5.4s to complete
#     error(train)=2.84e-01, acc(train)=8.92e-01, error(valid)=5.70e-01, acc(valid)=8.31e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 41: 13.6s to complete
#     error(train)=2.88e-01, acc(train)=8.92e-01, error(valid)=5.80e-01, acc(valid)=8.34e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 42: 8.4s to complete
#     error(train)=2.97e-01, acc(train)=8.90e-01, error(valid)=5.94e-01, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 43: 8.0s to complete
#     error(train)=2.85e-01, acc(train)=8.91e-01, error(valid)=5.79e-01, acc(valid)=8.30e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 44: 7.4s to complete
#     error(train)=2.82e-01, acc(train)=8.94e-01, error(valid)=5.86e-01, acc(valid)=8.29e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 45: 7.3s to complete
#     error(train)=2.83e-01, acc(train)=8.93e-01, error(valid)=5.92e-01, acc(valid)=8.31e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 46: 7.2s to complete
#     error(train)=2.77e-01, acc(train)=8.95e-01, error(valid)=5.86e-01, acc(valid)=8.31e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 47: 8.6s to complete
#     error(train)=2.79e-01, acc(train)=8.94e-01, error(valid)=5.99e-01, acc(valid)=8.30e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 48: 9.2s to complete
#     error(train)=2.78e-01, acc(train)=8.94e-01, error(valid)=5.95e-01, acc(valid)=8.32e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 49: 7.0s to complete
#     error(train)=2.75e-01, acc(train)=8.94e-01, error(valid)=5.99e-01, acc(valid)=8.29e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 50: 7.6s to complete
#     error(train)=2.75e-01, acc(train)=8.96e-01, error(valid)=5.85e-01, acc(valid)=8.31e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 51: 7.3s to complete
#     error(train)=2.73e-01, acc(train)=8.97e-01, error(valid)=6.06e-01, acc(valid)=8.32e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 52: 6.8s to complete
#     error(train)=2.80e-01, acc(train)=8.94e-01, error(valid)=6.10e-01, acc(valid)=8.29e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 53: 7.1s to complete
#     error(train)=2.74e-01, acc(train)=8.94e-01, error(valid)=6.10e-01, acc(valid)=8.27e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 54: 8.5s to complete
#     error(train)=2.73e-01, acc(train)=8.95e-01, error(valid)=6.13e-01, acc(valid)=8.29e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 55: 7.0s to complete
#     error(train)=2.59e-01, acc(train)=9.00e-01, error(valid)=6.11e-01, acc(valid)=8.30e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 56: 7.3s to complete
#     error(train)=2.66e-01, acc(train)=8.99e-01, error(valid)=6.15e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 57: 7.1s to complete
#     error(train)=2.63e-01, acc(train)=8.99e-01, error(valid)=6.17e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 58: 7.0s to complete
#     error(train)=2.57e-01, acc(train)=9.01e-01, error(valid)=6.22e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 59: 6.6s to complete
#     error(train)=2.54e-01, acc(train)=9.02e-01, error(valid)=6.18e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 60: 6.5s to complete
#     error(train)=2.55e-01, acc(train)=9.01e-01, error(valid)=6.28e-01, acc(valid)=8.33e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 61: 7.0s to complete
#     error(train)=2.59e-01, acc(train)=9.00e-01, error(valid)=6.37e-01, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 62: 7.4s to complete
#     error(train)=2.51e-01, acc(train)=9.05e-01, error(valid)=6.30e-01, acc(valid)=8.30e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 63: 6.9s to complete
#     error(train)=2.57e-01, acc(train)=9.00e-01, error(valid)=6.41e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 64: 7.5s to complete
#     error(train)=2.47e-01, acc(train)=9.03e-01, error(valid)=6.40e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 65: 7.5s to complete
#     error(train)=2.54e-01, acc(train)=9.01e-01, error(valid)=6.54e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 66: 7.1s to complete
#     error(train)=2.54e-01, acc(train)=9.02e-01, error(valid)=6.52e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 67: 6.7s to complete
#     error(train)=2.50e-01, acc(train)=9.01e-01, error(valid)=6.46e-01, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 68: 7.1s to complete
#     error(train)=2.59e-01, acc(train)=9.00e-01, error(valid)=6.69e-01, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 69: 7.0s to complete
#     error(train)=2.52e-01, acc(train)=9.02e-01, error(valid)=6.53e-01, acc(valid)=8.27e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 70: 7.1s to complete
#     error(train)=2.56e-01, acc(train)=9.00e-01, error(valid)=6.69e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 71: 10.5s to complete
#     error(train)=2.46e-01, acc(train)=9.04e-01, error(valid)=6.58e-01, acc(valid)=8.29e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 72: 9.5s to complete
#     error(train)=2.51e-01, acc(train)=9.02e-01, error(valid)=6.80e-01, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 73: 8.0s to complete
#     error(train)=2.39e-01, acc(train)=9.07e-01, error(valid)=6.75e-01, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 74: 5.8s to complete
#     error(train)=2.45e-01, acc(train)=9.05e-01, error(valid)=6.80e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 75: 5.8s to complete
#     error(train)=2.37e-01, acc(train)=9.07e-01, error(valid)=6.72e-01, acc(valid)=8.29e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 76: 6.1s to complete
#     error(train)=2.43e-01, acc(train)=9.05e-01, error(valid)=6.75e-01, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 77: 5.6s to complete
#     error(train)=2.47e-01, acc(train)=9.03e-01, error(valid)=6.88e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 78: 7.7s to complete
#     error(train)=2.44e-01, acc(train)=9.05e-01, error(valid)=6.88e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 79: 6.6s to complete
#     error(train)=2.49e-01, acc(train)=9.04e-01, error(valid)=6.90e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 80: 5.7s to complete
#     error(train)=2.44e-01, acc(train)=9.03e-01, error(valid)=6.93e-01, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 81: 6.5s to complete
#     error(train)=2.31e-01, acc(train)=9.09e-01, error(valid)=6.87e-01, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 82: 6.1s to complete
#     error(train)=2.35e-01, acc(train)=9.08e-01, error(valid)=7.10e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 83: 6.2s to complete
#     error(train)=2.34e-01, acc(train)=9.08e-01, error(valid)=7.00e-01, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 84: 5.9s to complete
#     error(train)=2.42e-01, acc(train)=9.05e-01, error(valid)=7.10e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 85: 6.1s to complete
#     error(train)=2.30e-01, acc(train)=9.08e-01, error(valid)=6.99e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 86: 6.4s to complete
#     error(train)=2.34e-01, acc(train)=9.07e-01, error(valid)=7.11e-01, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 87: 5.3s to complete
#     error(train)=2.33e-01, acc(train)=9.07e-01, error(valid)=7.12e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 88: 5.4s to complete
#     error(train)=2.39e-01, acc(train)=9.06e-01, error(valid)=7.14e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 89: 6.0s to complete
#     error(train)=2.26e-01, acc(train)=9.12e-01, error(valid)=7.14e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 90: 5.5s to complete
#     error(train)=2.27e-01, acc(train)=9.09e-01, error(valid)=7.09e-01, acc(valid)=8.27e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 91: 5.7s to complete
#     error(train)=2.27e-01, acc(train)=9.11e-01, error(valid)=7.02e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 92: 5.5s to complete
#     error(train)=2.41e-01, acc(train)=9.06e-01, error(valid)=7.36e-01, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 93: 7.3s to complete
#     error(train)=2.24e-01, acc(train)=9.12e-01, error(valid)=7.08e-01, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 94: 7.2s to complete
#     error(train)=2.41e-01, acc(train)=9.06e-01, error(valid)=7.30e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 95: 6.6s to complete
#     error(train)=2.19e-01, acc(train)=9.14e-01, error(valid)=7.24e-01, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 96: 7.3s to complete
#     error(train)=2.23e-01, acc(train)=9.11e-01, error(valid)=7.33e-01, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 97: 6.7s to complete
#     error(train)=2.19e-01, acc(train)=9.12e-01, error(valid)=7.28e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 98: 7.2s to complete
#     error(train)=2.30e-01, acc(train)=9.09e-01, error(valid)=7.30e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 99: 8.5s to complete
#     error(train)=2.31e-01, acc(train)=9.09e-01, error(valid)=7.56e-01, acc(valid)=8.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 100: 6.7s to complete
#     error(train)=2.18e-01, acc(train)=9.13e-01, error(valid)=7.38e-01, acc(valid)=8.24e-01
# OrderedDict([('error(test)', 0.8139473129225083), ('acc(test)', 0.8105063291139237)])

# %% [markdown]
# ## PRELU

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ParametricReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ParametricReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])
error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule()
#Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 1: 6.6s to complete
#     error(train)=8.87e-01, acc(train)=7.41e-01, error(valid)=9.05e-01, acc(valid)=7.35e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 2: 7.8s to complete
#     error(train)=7.65e-01, acc(train)=7.67e-01, error(valid)=7.97e-01, acc(valid)=7.51e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 3: 5.7s to complete
#     error(train)=6.23e-01, acc(train)=8.03e-01, error(valid)=6.69e-01, acc(valid)=7.90e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 4: 6.0s to complete
#     error(train)=6.25e-01, acc(train)=8.01e-01, error(valid)=6.75e-01, acc(valid)=7.88e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 5: 5.6s to complete
#     error(train)=5.26e-01, acc(train)=8.29e-01, error(valid)=5.88e-01, acc(valid)=8.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 6: 5.7s to complete
#     error(train)=5.28e-01, acc(train)=8.27e-01, error(valid)=6.02e-01, acc(valid)=8.06e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 7: 6.5s to complete
#     error(train)=4.66e-01, acc(train)=8.45e-01, error(valid)=5.54e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 8: 5.8s to complete
#     error(train)=4.43e-01, acc(train)=8.48e-01, error(valid)=5.41e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 9: 5.7s to complete
#     error(train)=4.63e-01, acc(train)=8.43e-01, error(valid)=5.68e-01, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 10: 5.7s to complete
#     error(train)=4.18e-01, acc(train)=8.58e-01, error(valid)=5.38e-01, acc(valid)=8.27e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 11: 5.8s to complete
#     error(train)=4.07e-01, acc(train)=8.60e-01, error(valid)=5.29e-01, acc(valid)=8.30e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 12: 5.6s to complete
#     error(train)=4.00e-01, acc(train)=8.59e-01, error(valid)=5.34e-01, acc(valid)=8.30e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 13: 5.7s to complete
#     error(train)=4.01e-01, acc(train)=8.61e-01, error(valid)=5.28e-01, acc(valid)=8.30e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 14: 5.9s to complete
#     error(train)=4.20e-01, acc(train)=8.52e-01, error(valid)=5.46e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 15: 5.8s to complete
#     error(train)=3.87e-01, acc(train)=8.63e-01, error(valid)=5.32e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 16: 5.9s to complete
#     error(train)=3.55e-01, acc(train)=8.75e-01, error(valid)=5.13e-01, acc(valid)=8.38e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 17: 6.3s to complete
#     error(train)=3.48e-01, acc(train)=8.75e-01, error(valid)=5.17e-01, acc(valid)=8.35e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 18: 6.5s to complete
#     error(train)=3.61e-01, acc(train)=8.71e-01, error(valid)=5.38e-01, acc(valid)=8.30e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 19: 5.7s to complete
#     error(train)=3.53e-01, acc(train)=8.73e-01, error(valid)=5.35e-01, acc(valid)=8.33e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 20: 6.1s to complete
#     error(train)=3.34e-01, acc(train)=8.79e-01, error(valid)=5.22e-01, acc(valid)=8.33e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 21: 7.0s to complete
#     error(train)=3.73e-01, acc(train)=8.66e-01, error(valid)=5.61e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 22: 6.0s to complete
#     error(train)=3.45e-01, acc(train)=8.76e-01, error(valid)=5.40e-01, acc(valid)=8.36e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 23: 8.0s to complete
#     error(train)=3.38e-01, acc(train)=8.76e-01, error(valid)=5.47e-01, acc(valid)=8.30e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 24: 7.9s to complete
#     error(train)=3.20e-01, acc(train)=8.83e-01, error(valid)=5.42e-01, acc(valid)=8.34e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 25: 5.5s to complete
#     error(train)=3.38e-01, acc(train)=8.76e-01, error(valid)=5.57e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 26: 6.3s to complete
#     error(train)=3.03e-01, acc(train)=8.89e-01, error(valid)=5.43e-01, acc(valid)=8.37e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 27: 8.4s to complete
#     error(train)=3.11e-01, acc(train)=8.85e-01, error(valid)=5.47e-01, acc(valid)=8.32e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 28: 7.6s to complete
#     error(train)=2.93e-01, acc(train)=8.92e-01, error(valid)=5.45e-01, acc(valid)=8.36e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 29: 5.9s to complete
#     error(train)=2.96e-01, acc(train)=8.91e-01, error(valid)=5.57e-01, acc(valid)=8.36e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 30: 5.9s to complete
#     error(train)=3.56e-01, acc(train)=8.68e-01, error(valid)=6.13e-01, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 31: 5.4s to complete
#     error(train)=2.93e-01, acc(train)=8.92e-01, error(valid)=5.69e-01, acc(valid)=8.32e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 32: 8.1s to complete
#     error(train)=2.80e-01, acc(train)=8.96e-01, error(valid)=5.63e-01, acc(valid)=8.37e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 33: 8.6s to complete
#     error(train)=2.88e-01, acc(train)=8.92e-01, error(valid)=5.78e-01, acc(valid)=8.34e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 34: 8.1s to complete
#     error(train)=2.75e-01, acc(train)=8.97e-01, error(valid)=5.78e-01, acc(valid)=8.39e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 35: 9.4s to complete
#     error(train)=2.83e-01, acc(train)=8.95e-01, error(valid)=5.94e-01, acc(valid)=8.35e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 36: 5.6s to complete
#     error(train)=2.82e-01, acc(train)=8.94e-01, error(valid)=5.89e-01, acc(valid)=8.33e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 37: 5.6s to complete
#     error(train)=2.80e-01, acc(train)=8.95e-01, error(valid)=5.88e-01, acc(valid)=8.33e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 38: 6.0s to complete
#     error(train)=2.79e-01, acc(train)=8.93e-01, error(valid)=5.99e-01, acc(valid)=8.30e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 39: 5.5s to complete
#     error(train)=2.89e-01, acc(train)=8.90e-01, error(valid)=6.12e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 40: 5.5s to complete
#     error(train)=2.76e-01, acc(train)=8.94e-01, error(valid)=6.16e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 41: 5.4s to complete
#     error(train)=2.63e-01, acc(train)=8.99e-01, error(valid)=6.12e-01, acc(valid)=8.32e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 42: 5.7s to complete
#     error(train)=2.67e-01, acc(train)=8.98e-01, error(valid)=6.23e-01, acc(valid)=8.30e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 43: 5.8s to complete
#     error(train)=2.66e-01, acc(train)=8.97e-01, error(valid)=6.38e-01, acc(valid)=8.27e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 44: 5.1s to complete
#     error(train)=2.65e-01, acc(train)=8.99e-01, error(valid)=6.32e-01, acc(valid)=8.31e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 45: 5.2s to complete
#     error(train)=2.46e-01, acc(train)=9.06e-01, error(valid)=6.21e-01, acc(valid)=8.32e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 46: 5.5s to complete
#     error(train)=2.62e-01, acc(train)=9.00e-01, error(valid)=6.49e-01, acc(valid)=8.30e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 47: 5.5s to complete
#     error(train)=2.45e-01, acc(train)=9.06e-01, error(valid)=6.41e-01, acc(valid)=8.33e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 48: 5.0s to complete
#     error(train)=2.48e-01, acc(train)=9.04e-01, error(valid)=6.51e-01, acc(valid)=8.31e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 49: 5.7s to complete
#     error(train)=2.45e-01, acc(train)=9.06e-01, error(valid)=6.48e-01, acc(valid)=8.31e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 50: 5.5s to complete
#     error(train)=2.52e-01, acc(train)=9.02e-01, error(valid)=6.56e-01, acc(valid)=8.30e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 51: 5.1s to complete
#     error(train)=2.57e-01, acc(train)=9.00e-01, error(valid)=6.80e-01, acc(valid)=8.30e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 52: 5.1s to complete
#     error(train)=2.43e-01, acc(train)=9.07e-01, error(valid)=6.75e-01, acc(valid)=8.34e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 53: 5.6s to complete
#     error(train)=2.60e-01, acc(train)=8.98e-01, error(valid)=6.99e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 54: 5.4s to complete
#     error(train)=2.38e-01, acc(train)=9.07e-01, error(valid)=6.82e-01, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 55: 5.8s to complete
#     error(train)=2.70e-01, acc(train)=8.96e-01, error(valid)=7.05e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 56: 6.4s to complete
#     error(train)=2.34e-01, acc(train)=9.08e-01, error(valid)=6.90e-01, acc(valid)=8.29e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 57: 5.9s to complete
#     error(train)=2.24e-01, acc(train)=9.14e-01, error(valid)=7.03e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 58: 5.4s to complete
#     error(train)=2.25e-01, acc(train)=9.12e-01, error(valid)=7.05e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 59: 6.0s to complete
#     error(train)=3.51e-01, acc(train)=8.70e-01, error(valid)=8.22e-01, acc(valid)=8.09e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 60: 5.8s to complete
#     error(train)=2.32e-01, acc(train)=9.10e-01, error(valid)=7.30e-01, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 61: 5.6s to complete
#     error(train)=3.04e-01, acc(train)=8.85e-01, error(valid)=8.10e-01, acc(valid)=8.11e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 62: 5.3s to complete
#     error(train)=2.31e-01, acc(train)=9.09e-01, error(valid)=7.43e-01, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 63: 5.9s to complete
#     error(train)=2.26e-01, acc(train)=9.10e-01, error(valid)=7.54e-01, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 64: 6.0s to complete
#     error(train)=2.17e-01, acc(train)=9.14e-01, error(valid)=7.56e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 65: 5.7s to complete
#     error(train)=2.21e-01, acc(train)=9.13e-01, error(valid)=7.63e-01, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 66: 5.9s to complete
#     error(train)=2.72e-01, acc(train)=8.94e-01, error(valid)=7.86e-01, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 67: 5.9s to complete
#     error(train)=2.55e-01, acc(train)=9.00e-01, error(valid)=8.05e-01, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 68: 5.3s to complete
#     error(train)=2.25e-01, acc(train)=9.11e-01, error(valid)=7.85e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 69: 6.2s to complete
#     error(train)=2.28e-01, acc(train)=9.09e-01, error(valid)=7.97e-01, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 70: 5.8s to complete
#     error(train)=2.88e-01, acc(train)=8.89e-01, error(valid)=8.78e-01, acc(valid)=8.09e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 71: 6.0s to complete
#     error(train)=2.12e-01, acc(train)=9.17e-01, error(valid)=8.04e-01, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 72: 5.5s to complete
#     error(train)=2.14e-01, acc(train)=9.14e-01, error(valid)=8.21e-01, acc(valid)=8.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 73: 5.8s to complete
#     error(train)=2.05e-01, acc(train)=9.19e-01, error(valid)=8.12e-01, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 74: 5.8s to complete
#     error(train)=2.19e-01, acc(train)=9.14e-01, error(valid)=8.35e-01, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 75: 5.2s to complete
#     error(train)=2.54e-01, acc(train)=9.01e-01, error(valid)=8.53e-01, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 76: 5.8s to complete
#     error(train)=1.99e-01, acc(train)=9.19e-01, error(valid)=8.32e-01, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 77: 5.9s to complete
#     error(train)=2.15e-01, acc(train)=9.12e-01, error(valid)=8.55e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 78: 5.4s to complete
#     error(train)=2.02e-01, acc(train)=9.18e-01, error(valid)=8.51e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 79: 5.4s to complete
#     error(train)=2.04e-01, acc(train)=9.18e-01, error(valid)=8.67e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 80: 6.0s to complete
#     error(train)=2.85e-01, acc(train)=8.89e-01, error(valid)=9.30e-01, acc(valid)=8.03e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 81: 6.0s to complete
#     error(train)=1.98e-01, acc(train)=9.20e-01, error(valid)=8.78e-01, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 82: 5.3s to complete
#     error(train)=1.95e-01, acc(train)=9.21e-01, error(valid)=8.79e-01, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 83: 5.7s to complete
#     error(train)=1.90e-01, acc(train)=9.23e-01, error(valid)=8.87e-01, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 84: 5.9s to complete
#     error(train)=2.02e-01, acc(train)=9.18e-01, error(valid)=9.09e-01, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 85: 5.5s to complete
#     error(train)=1.98e-01, acc(train)=9.19e-01, error(valid)=9.08e-01, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 86: 5.9s to complete
#     error(train)=1.96e-01, acc(train)=9.21e-01, error(valid)=8.94e-01, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 87: 6.1s to complete
#     error(train)=2.16e-01, acc(train)=9.14e-01, error(valid)=9.25e-01, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 88: 6.4s to complete
#     error(train)=1.82e-01, acc(train)=9.25e-01, error(valid)=9.12e-01, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 89: 5.5s to complete
#     error(train)=1.87e-01, acc(train)=9.24e-01, error(valid)=9.26e-01, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 90: 5.9s to complete
#     error(train)=2.23e-01, acc(train)=9.12e-01, error(valid)=9.62e-01, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 91: 5.9s to complete
#     error(train)=2.01e-01, acc(train)=9.19e-01, error(valid)=9.62e-01, acc(valid)=8.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 92: 5.5s to complete
#     error(train)=1.97e-01, acc(train)=9.20e-01, error(valid)=9.69e-01, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 93: 5.9s to complete
#     error(train)=2.17e-01, acc(train)=9.13e-01, error(valid)=9.70e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 94: 5.9s to complete
#     error(train)=2.81e-01, acc(train)=8.94e-01, error(valid)=1.03e+00, acc(valid)=8.09e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 95: 5.5s to complete
#     error(train)=1.80e-01, acc(train)=9.26e-01, error(valid)=9.70e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 96: 5.5s to complete
#     error(train)=1.69e-01, acc(train)=9.30e-01, error(valid)=9.82e-01, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 97: 6.4s to complete
#     error(train)=1.82e-01, acc(train)=9.24e-01, error(valid)=9.90e-01, acc(valid)=8.17e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 98: 5.5s to complete
#     error(train)=2.11e-01, acc(train)=9.15e-01, error(valid)=1.01e+00, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 99: 5.5s to complete
#     error(train)=1.73e-01, acc(train)=9.29e-01, error(valid)=1.01e+00, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 100: 6.1s to complete
#     error(train)=1.72e-01, acc(train)=9.30e-01, error(valid)=1.04e+00, acc(valid)=8.16e-01

# %% [markdown]
# ## ELU

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ExponentialLinearUnitLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ExponentialLinearUnitLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])
error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule()
#Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

# %% [markdown]
# ## 4.2 Baseline

# %% [markdown]
# ### hidden units 32, hidden layers 1

# %%
#Base Line ReLu
# Reset random number generator and data provider states on each run
# to ensure reproducibility of results
rng.seed(seed)
train_data.reset()
valid_data.reset()
#setup hyperparameters
learning_rate = 0.05
num_epochs = 100
stats_interval = 1
input_dim, output_dim = 784, 47
hidden_dim = 32

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),  
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule()

#Remember to use notebook=False when you write a script to be run in a terminal
#return stats, keys, run_time, fig_1, ax_1, fig_2, ax_2
stats_u32_h1, keys, run_time, fig_1_u32_h1, ax_1, fig_2_u32_h1, ax_2 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 1: 2.9s to complete
#     error(train)=1.23e+00, acc(train)=6.56e-01, error(valid)=1.23e+00, acc(valid)=6.55e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 2: 3.2s to complete
#     error(train)=1.12e+00, acc(train)=6.84e-01, error(valid)=1.13e+00, acc(valid)=6.77e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 3: 2.6s to complete
#     error(train)=1.04e+00, acc(train)=7.06e-01, error(valid)=1.06e+00, acc(valid)=7.03e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 4: 3.6s to complete
#     error(train)=9.74e-01, acc(train)=7.21e-01, error(valid)=9.98e-01, acc(valid)=7.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 5: 3.8s to complete
#     error(train)=9.34e-01, acc(train)=7.32e-01, error(valid)=9.63e-01, acc(valid)=7.27e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 6: 3.2s to complete
#     error(train)=9.02e-01, acc(train)=7.39e-01, error(valid)=9.31e-01, acc(valid)=7.33e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 7: 3.2s to complete
#     error(train)=8.63e-01, acc(train)=7.49e-01, error(valid)=8.99e-01, acc(valid)=7.41e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 8: 2.7s to complete
#     error(train)=8.43e-01, acc(train)=7.53e-01, error(valid)=8.80e-01, acc(valid)=7.42e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 9: 3.4s to complete
#     error(train)=8.24e-01, acc(train)=7.56e-01, error(valid)=8.67e-01, acc(valid)=7.48e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 10: 2.5s to complete
#     error(train)=8.03e-01, acc(train)=7.61e-01, error(valid)=8.46e-01, acc(valid)=7.52e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 11: 2.8s to complete
#     error(train)=7.87e-01, acc(train)=7.65e-01, error(valid)=8.36e-01, acc(valid)=7.50e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 12: 3.1s to complete
#     error(train)=7.66e-01, acc(train)=7.72e-01, error(valid)=8.15e-01, acc(valid)=7.57e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 13: 2.9s to complete
#     error(train)=7.56e-01, acc(train)=7.70e-01, error(valid)=8.06e-01, acc(valid)=7.58e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 14: 2.5s to complete
#     error(train)=7.41e-01, acc(train)=7.75e-01, error(valid)=8.00e-01, acc(valid)=7.58e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 15: 2.7s to complete
#     error(train)=7.43e-01, acc(train)=7.75e-01, error(valid)=8.00e-01, acc(valid)=7.60e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 16: 2.6s to complete
#     error(train)=7.18e-01, acc(train)=7.81e-01, error(valid)=7.79e-01, acc(valid)=7.67e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 17: 3.1s to complete
#     error(train)=7.11e-01, acc(train)=7.84e-01, error(valid)=7.72e-01, acc(valid)=7.66e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 18: 3.6s to complete
#     error(train)=7.10e-01, acc(train)=7.82e-01, error(valid)=7.74e-01, acc(valid)=7.63e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 19: 3.3s to complete
#     error(train)=6.99e-01, acc(train)=7.85e-01, error(valid)=7.68e-01, acc(valid)=7.68e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 20: 3.2s to complete
#     error(train)=6.99e-01, acc(train)=7.86e-01, error(valid)=7.66e-01, acc(valid)=7.68e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 21: 4.0s to complete
#     error(train)=6.83e-01, acc(train)=7.90e-01, error(valid)=7.55e-01, acc(valid)=7.73e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 22: 3.9s to complete
#     error(train)=6.79e-01, acc(train)=7.92e-01, error(valid)=7.52e-01, acc(valid)=7.76e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 23: 2.7s to complete
#     error(train)=6.72e-01, acc(train)=7.92e-01, error(valid)=7.44e-01, acc(valid)=7.75e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 24: 2.8s to complete
#     error(train)=6.68e-01, acc(train)=7.94e-01, error(valid)=7.40e-01, acc(valid)=7.77e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 25: 2.8s to complete
#     error(train)=6.65e-01, acc(train)=7.95e-01, error(valid)=7.44e-01, acc(valid)=7.75e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 26: 3.3s to complete
#     error(train)=6.57e-01, acc(train)=7.97e-01, error(valid)=7.37e-01, acc(valid)=7.76e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 27: 2.8s to complete
#     error(train)=6.61e-01, acc(train)=7.94e-01, error(valid)=7.40e-01, acc(valid)=7.73e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 28: 3.0s to complete
#     error(train)=6.59e-01, acc(train)=7.96e-01, error(valid)=7.38e-01, acc(valid)=7.75e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 29: 2.7s to complete
#     error(train)=6.52e-01, acc(train)=7.98e-01, error(valid)=7.37e-01, acc(valid)=7.76e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 30: 2.7s to complete
#     error(train)=6.47e-01, acc(train)=7.99e-01, error(valid)=7.30e-01, acc(valid)=7.81e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 31: 3.6s to complete
#     error(train)=6.46e-01, acc(train)=7.99e-01, error(valid)=7.33e-01, acc(valid)=7.77e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 32: 3.8s to complete
#     error(train)=6.41e-01, acc(train)=8.02e-01, error(valid)=7.27e-01, acc(valid)=7.82e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 33: 3.3s to complete
#     error(train)=6.34e-01, acc(train)=8.03e-01, error(valid)=7.21e-01, acc(valid)=7.84e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 34: 2.7s to complete
#     error(train)=6.38e-01, acc(train)=8.01e-01, error(valid)=7.25e-01, acc(valid)=7.80e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 35: 2.6s to complete
#     error(train)=6.37e-01, acc(train)=8.00e-01, error(valid)=7.26e-01, acc(valid)=7.79e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 36: 3.6s to complete
#     error(train)=6.32e-01, acc(train)=8.03e-01, error(valid)=7.22e-01, acc(valid)=7.82e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 37: 3.3s to complete
#     error(train)=6.29e-01, acc(train)=8.03e-01, error(valid)=7.20e-01, acc(valid)=7.80e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 38: 4.1s to complete
#     error(train)=6.28e-01, acc(train)=8.03e-01, error(valid)=7.24e-01, acc(valid)=7.83e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 39: 2.6s to complete
#     error(train)=6.24e-01, acc(train)=8.04e-01, error(valid)=7.20e-01, acc(valid)=7.80e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 40: 3.8s to complete
#     error(train)=6.26e-01, acc(train)=8.04e-01, error(valid)=7.22e-01, acc(valid)=7.81e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 41: 3.1s to complete
#     error(train)=6.20e-01, acc(train)=8.06e-01, error(valid)=7.18e-01, acc(valid)=7.85e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 42: 5.8s to complete
#     error(train)=6.22e-01, acc(train)=8.04e-01, error(valid)=7.23e-01, acc(valid)=7.83e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 43: 3.7s to complete
#     error(train)=6.28e-01, acc(train)=8.02e-01, error(valid)=7.27e-01, acc(valid)=7.78e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 44: 2.8s to complete
#     error(train)=6.14e-01, acc(train)=8.07e-01, error(valid)=7.13e-01, acc(valid)=7.84e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 45: 3.0s to complete
#     error(train)=6.14e-01, acc(train)=8.07e-01, error(valid)=7.17e-01, acc(valid)=7.86e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 46: 2.4s to complete
#     error(train)=6.16e-01, acc(train)=8.06e-01, error(valid)=7.23e-01, acc(valid)=7.84e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 47: 2.7s to complete
#     error(train)=6.13e-01, acc(train)=8.07e-01, error(valid)=7.23e-01, acc(valid)=7.83e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 48: 2.3s to complete
#     error(train)=6.08e-01, acc(train)=8.10e-01, error(valid)=7.13e-01, acc(valid)=7.87e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 49: 2.3s to complete
#     error(train)=6.08e-01, acc(train)=8.09e-01, error(valid)=7.19e-01, acc(valid)=7.84e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 50: 2.2s to complete
#     error(train)=6.08e-01, acc(train)=8.08e-01, error(valid)=7.19e-01, acc(valid)=7.83e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 51: 2.1s to complete
#     error(train)=6.01e-01, acc(train)=8.11e-01, error(valid)=7.12e-01, acc(valid)=7.87e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 52: 2.2s to complete
#     error(train)=6.01e-01, acc(train)=8.10e-01, error(valid)=7.12e-01, acc(valid)=7.86e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 53: 2.3s to complete
#     error(train)=5.98e-01, acc(train)=8.11e-01, error(valid)=7.11e-01, acc(valid)=7.83e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 54: 2.3s to complete
#     error(train)=6.01e-01, acc(train)=8.11e-01, error(valid)=7.16e-01, acc(valid)=7.85e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 55: 2.2s to complete
#     error(train)=5.92e-01, acc(train)=8.14e-01, error(valid)=7.06e-01, acc(valid)=7.88e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 56: 2.3s to complete
#     error(train)=5.94e-01, acc(train)=8.12e-01, error(valid)=7.13e-01, acc(valid)=7.84e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 57: 2.4s to complete
#     error(train)=5.94e-01, acc(train)=8.14e-01, error(valid)=7.13e-01, acc(valid)=7.86e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 58: 4.0s to complete
#     error(train)=5.94e-01, acc(train)=8.12e-01, error(valid)=7.14e-01, acc(valid)=7.83e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 59: 4.2s to complete
#     error(train)=5.94e-01, acc(train)=8.13e-01, error(valid)=7.15e-01, acc(valid)=7.84e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 60: 3.3s to complete
#     error(train)=5.89e-01, acc(train)=8.14e-01, error(valid)=7.11e-01, acc(valid)=7.88e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 61: 3.8s to complete
#     error(train)=5.96e-01, acc(train)=8.11e-01, error(valid)=7.18e-01, acc(valid)=7.83e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 62: 3.9s to complete
#     error(train)=5.85e-01, acc(train)=8.15e-01, error(valid)=7.08e-01, acc(valid)=7.86e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 63: 2.9s to complete
#     error(train)=5.93e-01, acc(train)=8.13e-01, error(valid)=7.20e-01, acc(valid)=7.85e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 64: 4.2s to complete
#     error(train)=5.88e-01, acc(train)=8.15e-01, error(valid)=7.13e-01, acc(valid)=7.84e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 65: 3.5s to complete
#     error(train)=5.91e-01, acc(train)=8.13e-01, error(valid)=7.14e-01, acc(valid)=7.85e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 66: 4.1s to complete
#     error(train)=5.85e-01, acc(train)=8.15e-01, error(valid)=7.08e-01, acc(valid)=7.87e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 67: 3.0s to complete
#     error(train)=5.80e-01, acc(train)=8.18e-01, error(valid)=7.09e-01, acc(valid)=7.88e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 68: 3.4s to complete
#     error(train)=5.81e-01, acc(train)=8.17e-01, error(valid)=7.11e-01, acc(valid)=7.88e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 69: 4.1s to complete
#     error(train)=5.83e-01, acc(train)=8.16e-01, error(valid)=7.12e-01, acc(valid)=7.86e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 70: 3.0s to complete
#     error(train)=5.86e-01, acc(train)=8.14e-01, error(valid)=7.18e-01, acc(valid)=7.83e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 71: 3.2s to complete
#     error(train)=5.85e-01, acc(train)=8.14e-01, error(valid)=7.17e-01, acc(valid)=7.84e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 72: 2.9s to complete
#     error(train)=5.79e-01, acc(train)=8.17e-01, error(valid)=7.14e-01, acc(valid)=7.85e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 73: 4.2s to complete
#     error(train)=5.78e-01, acc(train)=8.17e-01, error(valid)=7.11e-01, acc(valid)=7.87e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 74: 3.3s to complete
#     error(train)=5.80e-01, acc(train)=8.16e-01, error(valid)=7.14e-01, acc(valid)=7.89e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 75: 2.8s to complete
#     error(train)=5.83e-01, acc(train)=8.13e-01, error(valid)=7.18e-01, acc(valid)=7.82e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 76: 3.4s to complete
#     error(train)=5.76e-01, acc(train)=8.19e-01, error(valid)=7.11e-01, acc(valid)=7.86e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 77: 3.3s to complete
#     error(train)=5.77e-01, acc(train)=8.18e-01, error(valid)=7.17e-01, acc(valid)=7.85e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 78: 2.7s to complete
#     error(train)=5.75e-01, acc(train)=8.18e-01, error(valid)=7.13e-01, acc(valid)=7.86e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 79: 3.0s to complete
#     error(train)=5.75e-01, acc(train)=8.19e-01, error(valid)=7.14e-01, acc(valid)=7.87e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 80: 7.6s to complete
#     error(train)=5.71e-01, acc(train)=8.18e-01, error(valid)=7.08e-01, acc(valid)=7.87e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 81: 2.8s to complete
#     error(train)=5.75e-01, acc(train)=8.19e-01, error(valid)=7.17e-01, acc(valid)=7.85e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 82: 3.5s to complete
#     error(train)=5.81e-01, acc(train)=8.16e-01, error(valid)=7.19e-01, acc(valid)=7.83e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 83: 3.9s to complete
#     error(train)=5.73e-01, acc(train)=8.19e-01, error(valid)=7.17e-01, acc(valid)=7.85e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 84: 2.4s to complete
#     error(train)=5.69e-01, acc(train)=8.21e-01, error(valid)=7.12e-01, acc(valid)=7.86e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 85: 2.3s to complete
#     error(train)=5.77e-01, acc(train)=8.18e-01, error(valid)=7.20e-01, acc(valid)=7.86e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 86: 2.3s to complete
#     error(train)=5.71e-01, acc(train)=8.19e-01, error(valid)=7.17e-01, acc(valid)=7.85e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 87: 3.3s to complete
#     error(train)=5.71e-01, acc(train)=8.21e-01, error(valid)=7.18e-01, acc(valid)=7.85e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 88: 2.3s to complete
#     error(train)=5.71e-01, acc(train)=8.20e-01, error(valid)=7.18e-01, acc(valid)=7.86e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 89: 2.3s to complete
#     error(train)=5.68e-01, acc(train)=8.20e-01, error(valid)=7.17e-01, acc(valid)=7.83e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 90: 3.4s to complete
#     error(train)=5.78e-01, acc(train)=8.16e-01, error(valid)=7.29e-01, acc(valid)=7.81e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 91: 2.5s to complete
#     error(train)=5.66e-01, acc(train)=8.21e-01, error(valid)=7.15e-01, acc(valid)=7.83e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 92: 3.1s to complete
#     error(train)=5.65e-01, acc(train)=8.20e-01, error(valid)=7.14e-01, acc(valid)=7.82e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 93: 2.5s to complete
#     error(train)=5.63e-01, acc(train)=8.21e-01, error(valid)=7.15e-01, acc(valid)=7.85e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 94: 3.7s to complete
#     error(train)=5.74e-01, acc(train)=8.18e-01, error(valid)=7.25e-01, acc(valid)=7.81e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 95: 3.6s to complete
#     error(train)=5.64e-01, acc(train)=8.21e-01, error(valid)=7.16e-01, acc(valid)=7.84e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 96: 3.5s to complete
#     error(train)=5.67e-01, acc(train)=8.20e-01, error(valid)=7.21e-01, acc(valid)=7.83e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 97: 4.1s to complete
#     error(train)=5.64e-01, acc(train)=8.21e-01, error(valid)=7.16e-01, acc(valid)=7.85e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 98: 3.1s to complete
#     error(train)=5.70e-01, acc(train)=8.20e-01, error(valid)=7.24e-01, acc(valid)=7.81e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 99: 2.6s to complete
#     error(train)=5.63e-01, acc(train)=8.20e-01, error(valid)=7.19e-01, acc(valid)=7.83e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 100: 2.9s to complete
#     error(train)=5.65e-01, acc(train)=8.20e-01, error(valid)=7.17e-01, acc(valid)=7.85e-01
# OrderedDict([('error(test)', 0.7461863573703958), ('acc(test)', 0.7755063291139237)])

# %%
error_valid= stats_u32_h1[1:, keys['error(valid)']]
error_train= stats_u32_h1[1:, keys['error(train)']]
acc_train = stats_u32_h1[1:, keys['acc(train)']]
acc_valid = stats_u32_h1[1:, keys['acc(valid)']]
print('Best accuracy at Epoch={} by learning_rate={}, error(train)={}, error(valid)={}, acc(train)={}, acc(valid)={}'.
      format(np.argmax(acc_valid)+1,learning_rate, min(error_train), min(error_valid), max(acc_train), max(acc_valid)))
# Out:
# Best accuracy at Epoch=74 by learning_rate=0.1, error(train)=0.563204299685981, error(valid)=0.7061913799150439, acc(train)=0.8212500000000003, acc(valid)=0.7891772151898735

# %%
def evaluation(dataset,model):
    for inputs,targets in dataset:
        predictions = model.fprop(inputs,evaluation = True)[-1]
        accuracy = (predictions.argmax(-1) == targets.argmax(-1)).mean()
    print(i)
    return accuracy

test_acc = evaluation(test_data,model)
print(test_acc)
# Out:
# C:\Users\jycwy\Anaconda3\envs\mlp\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in log
# 158
# 0.78

# %% [markdown]
# ### hidden units 64, hidden layers 1

# %%
#Base Line ReLu
# Reset random number generator and data provider states on each run
# to ensure reproducibility of results
rng.seed(seed)
train_data.reset()
valid_data.reset()
#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim = 784, 47
hidden_dim = 64

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),  
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule()

#Remember to use notebook=False when you write a script to be run in a terminal
#return stats, keys, run_time, fig_1, ax_1, fig_2, ax_2
stats_u64_h1, keys, run_time, fig_1_u64_h1, ax_1, fig_2_u64_h1, ax_2 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 1: 3.6s to complete
#     error(train)=1.04e+00, acc(train)=7.04e-01, error(valid)=1.06e+00, acc(valid)=7.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 2: 3.9s to complete
#     error(train)=8.74e-01, acc(train)=7.47e-01, error(valid)=8.98e-01, acc(valid)=7.39e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 3: 3.7s to complete
#     error(train)=7.88e-01, acc(train)=7.69e-01, error(valid)=8.18e-01, acc(valid)=7.59e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 4: 3.5s to complete
#     error(train)=7.26e-01, acc(train)=7.82e-01, error(valid)=7.64e-01, acc(valid)=7.71e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 5: 4.4s to complete
#     error(train)=6.77e-01, acc(train)=7.95e-01, error(valid)=7.22e-01, acc(valid)=7.83e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 6: 4.1s to complete
#     error(train)=6.51e-01, acc(train)=7.99e-01, error(valid)=7.04e-01, acc(valid)=7.84e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 7: 4.3s to complete
#     error(train)=6.25e-01, acc(train)=8.06e-01, error(valid)=6.85e-01, acc(valid)=7.89e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 8: 3.9s to complete
#     error(train)=5.99e-01, acc(train)=8.16e-01, error(valid)=6.62e-01, acc(valid)=7.97e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 9: 3.5s to complete
#     error(train)=5.84e-01, acc(train)=8.19e-01, error(valid)=6.55e-01, acc(valid)=7.97e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 10: 3.4s to complete
#     error(train)=5.67e-01, acc(train)=8.22e-01, error(valid)=6.43e-01, acc(valid)=8.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 11: 3.7s to complete
#     error(train)=5.56e-01, acc(train)=8.25e-01, error(valid)=6.39e-01, acc(valid)=7.99e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 12: 3.5s to complete
#     error(train)=5.44e-01, acc(train)=8.29e-01, error(valid)=6.28e-01, acc(valid)=8.06e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 13: 3.7s to complete
#     error(train)=5.34e-01, acc(train)=8.30e-01, error(valid)=6.26e-01, acc(valid)=8.07e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 14: 3.6s to complete
#     error(train)=5.19e-01, acc(train)=8.35e-01, error(valid)=6.14e-01, acc(valid)=8.08e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 15: 4.1s to complete
#     error(train)=5.19e-01, acc(train)=8.33e-01, error(valid)=6.20e-01, acc(valid)=8.06e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 16: 3.6s to complete
#     error(train)=5.04e-01, acc(train)=8.38e-01, error(valid)=6.08e-01, acc(valid)=8.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 17: 3.7s to complete
#     error(train)=5.02e-01, acc(train)=8.38e-01, error(valid)=6.13e-01, acc(valid)=8.08e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 18: 3.9s to complete
#     error(train)=4.89e-01, acc(train)=8.41e-01, error(valid)=6.04e-01, acc(valid)=8.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 19: 4.1s to complete
#     error(train)=4.86e-01, acc(train)=8.41e-01, error(valid)=6.05e-01, acc(valid)=8.09e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 20: 6.5s to complete
#     error(train)=4.87e-01, acc(train)=8.43e-01, error(valid)=6.09e-01, acc(valid)=8.09e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 21: 3.6s to complete
#     error(train)=4.81e-01, acc(train)=8.44e-01, error(valid)=6.09e-01, acc(valid)=8.10e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 22: 3.6s to complete
#     error(train)=4.68e-01, acc(train)=8.46e-01, error(valid)=5.97e-01, acc(valid)=8.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 23: 3.5s to complete
#     error(train)=4.63e-01, acc(train)=8.49e-01, error(valid)=5.96e-01, acc(valid)=8.13e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 24: 5.9s to complete
#     error(train)=4.60e-01, acc(train)=8.48e-01, error(valid)=5.99e-01, acc(valid)=8.10e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 25: 5.4s to complete
#     error(train)=4.60e-01, acc(train)=8.49e-01, error(valid)=6.00e-01, acc(valid)=8.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 26: 4.4s to complete
#     error(train)=4.60e-01, acc(train)=8.48e-01, error(valid)=6.05e-01, acc(valid)=8.11e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 27: 4.1s to complete
#     error(train)=4.64e-01, acc(train)=8.44e-01, error(valid)=6.13e-01, acc(valid)=8.04e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 28: 3.6s to complete
#     error(train)=4.49e-01, acc(train)=8.52e-01, error(valid)=6.02e-01, acc(valid)=8.13e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 29: 3.6s to complete
#     error(train)=4.44e-01, acc(train)=8.53e-01, error(valid)=5.99e-01, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 30: 4.7s to complete
#     error(train)=4.47e-01, acc(train)=8.50e-01, error(valid)=6.02e-01, acc(valid)=8.08e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 31: 3.9s to complete
#     error(train)=4.37e-01, acc(train)=8.56e-01, error(valid)=5.98e-01, acc(valid)=8.13e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 32: 3.6s to complete
#     error(train)=4.46e-01, acc(train)=8.51e-01, error(valid)=6.03e-01, acc(valid)=8.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 33: 5.2s to complete
#     error(train)=4.42e-01, acc(train)=8.51e-01, error(valid)=6.07e-01, acc(valid)=8.08e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 34: 3.8s to complete
#     error(train)=4.29e-01, acc(train)=8.56e-01, error(valid)=6.00e-01, acc(valid)=8.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 35: 4.2s to complete
#     error(train)=4.24e-01, acc(train)=8.59e-01, error(valid)=5.94e-01, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 36: 3.7s to complete
#     error(train)=4.27e-01, acc(train)=8.57e-01, error(valid)=5.99e-01, acc(valid)=8.13e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 37: 4.4s to complete
#     error(train)=4.32e-01, acc(train)=8.56e-01, error(valid)=6.09e-01, acc(valid)=8.15e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 38: 4.3s to complete
#     error(train)=4.19e-01, acc(train)=8.59e-01, error(valid)=6.00e-01, acc(valid)=8.11e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 39: 4.2s to complete
#     error(train)=4.20e-01, acc(train)=8.59e-01, error(valid)=6.04e-01, acc(valid)=8.13e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 40: 4.9s to complete
#     error(train)=4.23e-01, acc(train)=8.60e-01, error(valid)=6.08e-01, acc(valid)=8.13e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 41: 3.8s to complete
#     error(train)=4.13e-01, acc(train)=8.62e-01, error(valid)=6.03e-01, acc(valid)=8.13e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 42: 3.9s to complete
#     error(train)=4.12e-01, acc(train)=8.60e-01, error(valid)=6.04e-01, acc(valid)=8.11e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 43: 4.1s to complete
#     error(train)=4.12e-01, acc(train)=8.61e-01, error(valid)=6.06e-01, acc(valid)=8.14e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 44: 3.5s to complete
#     error(train)=4.03e-01, acc(train)=8.65e-01, error(valid)=6.00e-01, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 45: 4.0s to complete
#     error(train)=4.09e-01, acc(train)=8.63e-01, error(valid)=6.05e-01, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 46: 3.9s to complete
#     error(train)=4.03e-01, acc(train)=8.62e-01, error(valid)=6.02e-01, acc(valid)=8.13e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 47: 3.5s to complete
#     error(train)=4.05e-01, acc(train)=8.61e-01, error(valid)=6.11e-01, acc(valid)=8.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 48: 3.5s to complete
#     error(train)=4.07e-01, acc(train)=8.62e-01, error(valid)=6.08e-01, acc(valid)=8.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 49: 3.6s to complete
#     error(train)=3.98e-01, acc(train)=8.65e-01, error(valid)=6.05e-01, acc(valid)=8.14e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 50: 3.5s to complete
#     error(train)=3.96e-01, acc(train)=8.65e-01, error(valid)=6.03e-01, acc(valid)=8.17e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 51: 3.5s to complete
#     error(train)=3.91e-01, acc(train)=8.68e-01, error(valid)=6.01e-01, acc(valid)=8.14e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 52: 3.6s to complete
#     error(train)=3.93e-01, acc(train)=8.67e-01, error(valid)=6.05e-01, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 53: 3.7s to complete
#     error(train)=3.94e-01, acc(train)=8.65e-01, error(valid)=6.12e-01, acc(valid)=8.15e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 54: 4.0s to complete
#     error(train)=3.92e-01, acc(train)=8.67e-01, error(valid)=6.10e-01, acc(valid)=8.15e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 55: 3.4s to complete
#     error(train)=3.89e-01, acc(train)=8.68e-01, error(valid)=6.13e-01, acc(valid)=8.13e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 56: 3.6s to complete
#     error(train)=3.86e-01, acc(train)=8.69e-01, error(valid)=6.10e-01, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 57: 3.5s to complete
#     error(train)=3.92e-01, acc(train)=8.64e-01, error(valid)=6.22e-01, acc(valid)=8.09e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 58: 3.8s to complete
#     error(train)=3.88e-01, acc(train)=8.69e-01, error(valid)=6.14e-01, acc(valid)=8.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 59: 3.6s to complete
#     error(train)=3.95e-01, acc(train)=8.64e-01, error(valid)=6.25e-01, acc(valid)=8.08e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 60: 4.9s to complete
#     error(train)=3.82e-01, acc(train)=8.71e-01, error(valid)=6.17e-01, acc(valid)=8.14e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 61: 3.9s to complete
#     error(train)=3.81e-01, acc(train)=8.71e-01, error(valid)=6.12e-01, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 62: 3.9s to complete
#     error(train)=3.87e-01, acc(train)=8.67e-01, error(valid)=6.26e-01, acc(valid)=8.13e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 63: 4.4s to complete
#     error(train)=3.81e-01, acc(train)=8.69e-01, error(valid)=6.23e-01, acc(valid)=8.11e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 64: 3.5s to complete
#     error(train)=3.77e-01, acc(train)=8.71e-01, error(valid)=6.16e-01, acc(valid)=8.14e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 65: 3.8s to complete
#     error(train)=3.84e-01, acc(train)=8.68e-01, error(valid)=6.30e-01, acc(valid)=8.11e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 66: 5.3s to complete
#     error(train)=3.76e-01, acc(train)=8.70e-01, error(valid)=6.23e-01, acc(valid)=8.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 67: 7.6s to complete
#     error(train)=3.73e-01, acc(train)=8.72e-01, error(valid)=6.24e-01, acc(valid)=8.15e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 68: 5.6s to complete
#     error(train)=3.68e-01, acc(train)=8.75e-01, error(valid)=6.21e-01, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 69: 4.2s to complete
#     error(train)=3.72e-01, acc(train)=8.74e-01, error(valid)=6.29e-01, acc(valid)=8.13e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 70: 3.7s to complete
#     error(train)=3.78e-01, acc(train)=8.70e-01, error(valid)=6.28e-01, acc(valid)=8.14e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 71: 4.0s to complete
#     error(train)=3.75e-01, acc(train)=8.70e-01, error(valid)=6.34e-01, acc(valid)=8.08e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 72: 3.6s to complete
#     error(train)=3.70e-01, acc(train)=8.72e-01, error(valid)=6.29e-01, acc(valid)=8.14e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 73: 3.7s to complete
#     error(train)=3.73e-01, acc(train)=8.71e-01, error(valid)=6.32e-01, acc(valid)=8.11e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 74: 3.5s to complete
#     error(train)=3.64e-01, acc(train)=8.75e-01, error(valid)=6.31e-01, acc(valid)=8.14e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 75: 3.5s to complete
#     error(train)=3.69e-01, acc(train)=8.73e-01, error(valid)=6.36e-01, acc(valid)=8.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 76: 3.6s to complete
#     error(train)=3.68e-01, acc(train)=8.74e-01, error(valid)=6.35e-01, acc(valid)=8.10e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 77: 3.5s to complete
#     error(train)=3.71e-01, acc(train)=8.72e-01, error(valid)=6.42e-01, acc(valid)=8.10e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 78: 3.6s to complete
#     error(train)=3.64e-01, acc(train)=8.75e-01, error(valid)=6.40e-01, acc(valid)=8.10e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 79: 3.6s to complete
#     error(train)=3.63e-01, acc(train)=8.74e-01, error(valid)=6.34e-01, acc(valid)=8.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 80: 3.8s to complete
#     error(train)=3.57e-01, acc(train)=8.78e-01, error(valid)=6.38e-01, acc(valid)=8.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 81: 3.5s to complete
#     error(train)=3.63e-01, acc(train)=8.74e-01, error(valid)=6.44e-01, acc(valid)=8.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 82: 3.5s to complete
#     error(train)=3.56e-01, acc(train)=8.76e-01, error(valid)=6.37e-01, acc(valid)=8.11e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 83: 3.5s to complete
#     error(train)=3.56e-01, acc(train)=8.77e-01, error(valid)=6.39e-01, acc(valid)=8.09e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 84: 6.7s to complete
#     error(train)=3.63e-01, acc(train)=8.75e-01, error(valid)=6.51e-01, acc(valid)=8.08e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 85: 4.9s to complete
#     error(train)=3.60e-01, acc(train)=8.75e-01, error(valid)=6.53e-01, acc(valid)=8.07e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 86: 4.1s to complete
#     error(train)=3.57e-01, acc(train)=8.76e-01, error(valid)=6.43e-01, acc(valid)=8.09e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 87: 4.8s to complete
#     error(train)=3.61e-01, acc(train)=8.75e-01, error(valid)=6.53e-01, acc(valid)=8.06e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 88: 4.1s to complete
#     error(train)=3.47e-01, acc(train)=8.81e-01, error(valid)=6.44e-01, acc(valid)=8.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 89: 5.4s to complete
#     error(train)=3.58e-01, acc(train)=8.75e-01, error(valid)=6.56e-01, acc(valid)=8.07e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 90: 4.6s to complete
#     error(train)=3.50e-01, acc(train)=8.80e-01, error(valid)=6.53e-01, acc(valid)=8.08e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 91: 3.6s to complete
#     error(train)=3.51e-01, acc(train)=8.79e-01, error(valid)=6.54e-01, acc(valid)=8.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 92: 3.6s to complete
#     error(train)=3.56e-01, acc(train)=8.75e-01, error(valid)=6.60e-01, acc(valid)=8.08e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 93: 3.6s to complete
#     error(train)=3.54e-01, acc(train)=8.78e-01, error(valid)=6.61e-01, acc(valid)=8.08e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 94: 3.8s to complete
#     error(train)=3.51e-01, acc(train)=8.78e-01, error(valid)=6.54e-01, acc(valid)=8.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 95: 3.8s to complete
#     error(train)=3.53e-01, acc(train)=8.77e-01, error(valid)=6.62e-01, acc(valid)=8.10e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 96: 3.5s to complete
#     error(train)=3.49e-01, acc(train)=8.79e-01, error(valid)=6.63e-01, acc(valid)=8.10e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 97: 4.0s to complete
#     error(train)=3.46e-01, acc(train)=8.79e-01, error(valid)=6.60e-01, acc(valid)=8.09e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 98: 3.7s to complete
#     error(train)=3.45e-01, acc(train)=8.80e-01, error(valid)=6.60e-01, acc(valid)=8.08e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 99: 3.7s to complete
#     error(train)=3.50e-01, acc(train)=8.77e-01, error(valid)=6.68e-01, acc(valid)=8.06e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 100: 3.5s to complete
#     error(train)=3.39e-01, acc(train)=8.82e-01, error(valid)=6.59e-01, acc(valid)=8.09e-01
# OrderedDict([('error(test)', 0.7178900123848733), ('acc(test)', 0.799493670886076)])

# %%
error_valid= stats_u64_h1[1:, keys['error(valid)']]
error_train= stats_u64_h1[1:, keys['error(train)']]
acc_train = stats_u64_h1[1:, keys['acc(train)']]
acc_valid = stats_u64_h1[1:, keys['acc(valid)']]
print('Best accuracy at Epoch={} by learning_rate={}, error(train)={}, error(valid)={}, acc(train)={}, acc(valid)={}'.
      format(np.argmax(acc_valid)+1,learning_rate, min(error_train), min(error_valid), max(acc_train), max(acc_valid)))

# %% [markdown]
# ### hidden units 128, hidden layers 1

# %%
#Base Line ReLu
# Reset random number generator and data provider states on each run
# to ensure reproducibility of results
rng.seed(seed)
train_data.reset()
valid_data.reset()
#setup hyperparameters
learning_rate = 1e-4
num_epochs = 100
stats_interval = 1
input_dim, output_dim = 784, 47
hidden_dim = 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),  
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule()

#Remember to use notebook=False when you write a script to be run in a terminal
#return stats, keys, run_time, fig_1, ax_1, fig_2, ax_2
_= train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 1: 9.7s to complete
#     error(train)=9.30e-01, acc(train)=7.32e-01, error(valid)=9.51e-01, acc(valid)=7.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 2: 9.9s to complete
#     error(train)=7.21e-01, acc(train)=7.86e-01, error(valid)=7.60e-01, acc(valid)=7.77e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 3: 7.8s to complete
#     error(train)=6.27e-01, acc(train)=8.06e-01, error(valid)=6.80e-01, acc(valid)=7.91e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 4: 7.4s to complete
#     error(train)=5.54e-01, acc(train)=8.27e-01, error(valid)=6.20e-01, acc(valid)=8.06e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 5: 9.2s to complete
#     error(train)=5.22e-01, acc(train)=8.35e-01, error(valid)=5.97e-01, acc(valid)=8.10e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 6: 5.6s to complete
#     error(train)=4.92e-01, acc(train)=8.40e-01, error(valid)=5.81e-01, acc(valid)=8.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 7: 9.9s to complete
#     error(train)=4.66e-01, acc(train)=8.49e-01, error(valid)=5.68e-01, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 8: 6.7s to complete
#     error(train)=4.37e-01, acc(train)=8.57e-01, error(valid)=5.44e-01, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 9: 7.4s to complete
#     error(train)=4.18e-01, acc(train)=8.62e-01, error(valid)=5.39e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 10: 7.8s to complete
#     error(train)=4.13e-01, acc(train)=8.62e-01, error(valid)=5.47e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 11: 6.5s to complete
#     error(train)=4.02e-01, acc(train)=8.64e-01, error(valid)=5.44e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 12: 7.1s to complete
#     error(train)=3.88e-01, acc(train)=8.69e-01, error(valid)=5.37e-01, acc(valid)=8.29e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 13: 7.0s to complete
#     error(train)=3.78e-01, acc(train)=8.72e-01, error(valid)=5.36e-01, acc(valid)=8.29e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 14: 6.2s to complete
#     error(train)=3.66e-01, acc(train)=8.76e-01, error(valid)=5.41e-01, acc(valid)=8.27e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 15: 8.6s to complete
#     error(train)=3.60e-01, acc(train)=8.77e-01, error(valid)=5.37e-01, acc(valid)=8.29e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 16: 9.4s to complete
#     error(train)=3.60e-01, acc(train)=8.74e-01, error(valid)=5.45e-01, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 17: 6.0s to complete
#     error(train)=3.40e-01, acc(train)=8.84e-01, error(valid)=5.34e-01, acc(valid)=8.32e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 18: 7.8s to complete
#     error(train)=3.44e-01, acc(train)=8.81e-01, error(valid)=5.50e-01, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 19: 9.7s to complete
#     error(train)=3.34e-01, acc(train)=8.85e-01, error(valid)=5.43e-01, acc(valid)=8.31e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 20: 9.7s to complete
#     error(train)=3.25e-01, acc(train)=8.86e-01, error(valid)=5.43e-01, acc(valid)=8.27e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 21: 7.5s to complete
#     error(train)=3.28e-01, acc(train)=8.84e-01, error(valid)=5.54e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 22: 6.6s to complete
#     error(train)=3.23e-01, acc(train)=8.86e-01, error(valid)=5.56e-01, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 23: 6.2s to complete
#     error(train)=3.10e-01, acc(train)=8.92e-01, error(valid)=5.53e-01, acc(valid)=8.27e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 24: 7.3s to complete
#     error(train)=3.07e-01, acc(train)=8.92e-01, error(valid)=5.61e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 25: 5.8s to complete
#     error(train)=2.98e-01, acc(train)=8.96e-01, error(valid)=5.54e-01, acc(valid)=8.34e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 26: 9.2s to complete
#     error(train)=3.00e-01, acc(train)=8.95e-01, error(valid)=5.70e-01, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 27: 8.4s to complete
#     error(train)=2.88e-01, acc(train)=8.97e-01, error(valid)=5.66e-01, acc(valid)=8.27e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 28: 6.5s to complete
#     error(train)=2.91e-01, acc(train)=8.97e-01, error(valid)=5.74e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 29: 9.5s to complete
#     error(train)=2.85e-01, acc(train)=8.99e-01, error(valid)=5.73e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 30: 5.5s to complete
#     error(train)=2.82e-01, acc(train)=9.00e-01, error(valid)=5.77e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 31: 9.1s to complete
#     error(train)=2.77e-01, acc(train)=9.01e-01, error(valid)=5.87e-01, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 32: 6.6s to complete
#     error(train)=2.76e-01, acc(train)=9.02e-01, error(valid)=5.89e-01, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 33: 8.3s to complete
#     error(train)=2.76e-01, acc(train)=9.01e-01, error(valid)=6.11e-01, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 34: 5.4s to complete
#     error(train)=2.79e-01, acc(train)=8.98e-01, error(valid)=6.13e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 35: 8.1s to complete
#     error(train)=2.64e-01, acc(train)=9.05e-01, error(valid)=6.02e-01, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 36: 7.4s to complete
#     error(train)=2.61e-01, acc(train)=9.06e-01, error(valid)=6.11e-01, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 37: 8.7s to complete
#     error(train)=2.56e-01, acc(train)=9.08e-01, error(valid)=6.09e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 38: 7.8s to complete
#     error(train)=2.52e-01, acc(train)=9.08e-01, error(valid)=6.11e-01, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 39: 7.2s to complete
#     error(train)=2.52e-01, acc(train)=9.09e-01, error(valid)=6.29e-01, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 40: 7.6s to complete
#     error(train)=2.43e-01, acc(train)=9.12e-01, error(valid)=6.19e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 41: 6.1s to complete
#     error(train)=2.43e-01, acc(train)=9.12e-01, error(valid)=6.26e-01, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 42: 8.8s to complete
#     error(train)=2.54e-01, acc(train)=9.07e-01, error(valid)=6.42e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 43: 7.8s to complete
#     error(train)=2.44e-01, acc(train)=9.11e-01, error(valid)=6.50e-01, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 44: 9.4s to complete
#     error(train)=2.38e-01, acc(train)=9.13e-01, error(valid)=6.41e-01, acc(valid)=8.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 45: 8.3s to complete
#     error(train)=2.48e-01, acc(train)=9.07e-01, error(valid)=6.54e-01, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 46: 7.1s to complete
#     error(train)=2.32e-01, acc(train)=9.16e-01, error(valid)=6.55e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 47: 6.8s to complete
#     error(train)=2.33e-01, acc(train)=9.14e-01, error(valid)=6.63e-01, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 48: 5.8s to complete
#     error(train)=2.22e-01, acc(train)=9.20e-01, error(valid)=6.64e-01, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 49: 8.0s to complete
#     error(train)=2.36e-01, acc(train)=9.13e-01, error(valid)=6.78e-01, acc(valid)=8.17e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 50: 9.6s to complete
#     error(train)=2.25e-01, acc(train)=9.17e-01, error(valid)=6.77e-01, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 51: 8.6s to complete
#     error(train)=2.22e-01, acc(train)=9.18e-01, error(valid)=6.79e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 52: 13.0s to complete
#     error(train)=2.19e-01, acc(train)=9.18e-01, error(valid)=6.97e-01, acc(valid)=8.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 53: 6.6s to complete
#     error(train)=2.29e-01, acc(train)=9.16e-01, error(valid)=7.08e-01, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 54: 7.0s to complete
#     error(train)=2.16e-01, acc(train)=9.20e-01, error(valid)=7.00e-01, acc(valid)=8.17e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 55: 7.2s to complete
#     error(train)=2.12e-01, acc(train)=9.22e-01, error(valid)=6.98e-01, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 56: 7.6s to complete
#     error(train)=2.17e-01, acc(train)=9.20e-01, error(valid)=7.14e-01, acc(valid)=8.15e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 57: 8.8s to complete
#     error(train)=2.13e-01, acc(train)=9.20e-01, error(valid)=7.23e-01, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 58: 5.7s to complete
#     error(train)=2.13e-01, acc(train)=9.21e-01, error(valid)=7.21e-01, acc(valid)=8.15e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 59: 9.6s to complete
#     error(train)=2.08e-01, acc(train)=9.23e-01, error(valid)=7.29e-01, acc(valid)=8.14e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 60: 11.3s to complete
#     error(train)=2.10e-01, acc(train)=9.22e-01, error(valid)=7.24e-01, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 61: 9.6s to complete
#     error(train)=2.06e-01, acc(train)=9.23e-01, error(valid)=7.40e-01, acc(valid)=8.13e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 62: 5.8s to complete
#     error(train)=1.96e-01, acc(train)=9.28e-01, error(valid)=7.33e-01, acc(valid)=8.14e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 63: 10.2s to complete
#     error(train)=1.95e-01, acc(train)=9.29e-01, error(valid)=7.46e-01, acc(valid)=8.15e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 64: 10.8s to complete
#     error(train)=2.06e-01, acc(train)=9.21e-01, error(valid)=7.65e-01, acc(valid)=8.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 65: 11.7s to complete
#     error(train)=1.97e-01, acc(train)=9.26e-01, error(valid)=7.59e-01, acc(valid)=8.14e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 66: 10.7s to complete
#     error(train)=1.96e-01, acc(train)=9.27e-01, error(valid)=7.61e-01, acc(valid)=8.14e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 67: 11.8s to complete
#     error(train)=1.97e-01, acc(train)=9.26e-01, error(valid)=7.76e-01, acc(valid)=8.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 68: 10.1s to complete
#     error(train)=2.06e-01, acc(train)=9.21e-01, error(valid)=7.95e-01, acc(valid)=8.07e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 69: 7.1s to complete
#     error(train)=1.91e-01, acc(train)=9.29e-01, error(valid)=7.80e-01, acc(valid)=8.14e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 70: 8.0s to complete
#     error(train)=2.03e-01, acc(train)=9.23e-01, error(valid)=7.92e-01, acc(valid)=8.09e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 71: 7.3s to complete
#     error(train)=1.91e-01, acc(train)=9.28e-01, error(valid)=7.96e-01, acc(valid)=8.13e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 72: 6.8s to complete
#     error(train)=1.88e-01, acc(train)=9.29e-01, error(valid)=8.01e-01, acc(valid)=8.09e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 73: 6.7s to complete
#     error(train)=1.86e-01, acc(train)=9.30e-01, error(valid)=8.08e-01, acc(valid)=8.06e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 74: 6.8s to complete
#     error(train)=1.86e-01, acc(train)=9.30e-01, error(valid)=8.12e-01, acc(valid)=8.10e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 75: 6.6s to complete
#     error(train)=1.78e-01, acc(train)=9.34e-01, error(valid)=8.16e-01, acc(valid)=8.13e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 76: 8.5s to complete
#     error(train)=1.87e-01, acc(train)=9.27e-01, error(valid)=8.34e-01, acc(valid)=8.07e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 77: 8.3s to complete
#     error(train)=1.83e-01, acc(train)=9.30e-01, error(valid)=8.31e-01, acc(valid)=8.10e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 78: 7.5s to complete
#     error(train)=1.85e-01, acc(train)=9.30e-01, error(valid)=8.33e-01, acc(valid)=8.10e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 79: 6.5s to complete
#     error(train)=1.75e-01, acc(train)=9.34e-01, error(valid)=8.43e-01, acc(valid)=8.08e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 80: 12.6s to complete
#     error(train)=1.78e-01, acc(train)=9.33e-01, error(valid)=8.47e-01, acc(valid)=8.11e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 81: 6.9s to complete
#     error(train)=1.72e-01, acc(train)=9.36e-01, error(valid)=8.48e-01, acc(valid)=8.07e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 82: 6.5s to complete
#     error(train)=1.75e-01, acc(train)=9.33e-01, error(valid)=8.55e-01, acc(valid)=8.08e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 83: 7.1s to complete
#     error(train)=1.70e-01, acc(train)=9.35e-01, error(valid)=8.64e-01, acc(valid)=8.11e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 84: 9.9s to complete
#     error(train)=1.69e-01, acc(train)=9.36e-01, error(valid)=8.64e-01, acc(valid)=8.14e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 85: 5.9s to complete
#     error(train)=1.73e-01, acc(train)=9.33e-01, error(valid)=8.72e-01, acc(valid)=8.08e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 86: 7.0s to complete
#     error(train)=1.67e-01, acc(train)=9.36e-01, error(valid)=8.79e-01, acc(valid)=8.07e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 87: 8.7s to complete
#     error(train)=1.76e-01, acc(train)=9.33e-01, error(valid)=9.06e-01, acc(valid)=8.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 88: 6.9s to complete
#     error(train)=1.76e-01, acc(train)=9.32e-01, error(valid)=9.09e-01, acc(valid)=8.04e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 89: 8.2s to complete
#     error(train)=1.76e-01, acc(train)=9.32e-01, error(valid)=9.13e-01, acc(valid)=8.06e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 90: 6.1s to complete
#     error(train)=1.63e-01, acc(train)=9.39e-01, error(valid)=9.13e-01, acc(valid)=8.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 91: 6.3s to complete
#     error(train)=1.59e-01, acc(train)=9.40e-01, error(valid)=9.10e-01, acc(valid)=8.10e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 92: 6.6s to complete
#     error(train)=1.57e-01, acc(train)=9.41e-01, error(valid)=9.14e-01, acc(valid)=8.09e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 93: 6.2s to complete
#     error(train)=1.63e-01, acc(train)=9.38e-01, error(valid)=9.26e-01, acc(valid)=8.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 94: 7.1s to complete
#     error(train)=1.63e-01, acc(train)=9.37e-01, error(valid)=9.36e-01, acc(valid)=8.08e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 95: 8.0s to complete
#     error(train)=1.61e-01, acc(train)=9.39e-01, error(valid)=9.45e-01, acc(valid)=8.09e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 96: 7.0s to complete
#     error(train)=1.57e-01, acc(train)=9.40e-01, error(valid)=9.42e-01, acc(valid)=8.10e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 97: 6.3s to complete
#     error(train)=1.62e-01, acc(train)=9.38e-01, error(valid)=9.60e-01, acc(valid)=8.07e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 98: 6.4s to complete
#     error(train)=1.57e-01, acc(train)=9.40e-01, error(valid)=9.61e-01, acc(valid)=8.09e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 99: 6.7s to complete
#     error(train)=1.54e-01, acc(train)=9.41e-01, error(valid)=9.56e-01, acc(valid)=8.08e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 100: 6.7s to complete
#     error(train)=1.56e-01, acc(train)=9.40e-01, error(valid)=9.83e-01, acc(valid)=8.03e-01
# OrderedDict([('error(test)', 1.0226117163944792), ('acc(test)', 0.7962025316455694)])

# %% [markdown]
# ### hidden unites 32, hidden layers 2

# %%
#Base Line ReLu
# Reset random number generator and data provider states on each run
# to ensure reproducibility of results
rng.seed(seed)
train_data.reset()
valid_data.reset()
#setup hyperparameters
learning_rate = 0.01
num_epochs = 100
stats_interval = 1
input_dim, output_dim = 784, 47
hidden_dim = 32

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule()

#Remember to use notebook=False when you write a script to be run in a terminal
#return stats, keys, run_time, fig_1, ax_1, fig_2, ax_2
stats_u32_h2, keys, run_time, fig_1_u32_h2, ax_1, fig_2_u32_h2, ax_2 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 1: 3.3s to complete
#     error(train)=1.20e+00, acc(train)=6.61e-01, error(valid)=1.21e+00, acc(valid)=6.52e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 2: 3.9s to complete
#     error(train)=1.02e+00, acc(train)=7.04e-01, error(valid)=1.04e+00, acc(valid)=7.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 3: 3.1s to complete
#     error(train)=9.19e-01, acc(train)=7.28e-01, error(valid)=9.43e-01, acc(valid)=7.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 4: 3.0s to complete
#     error(train)=8.51e-01, acc(train)=7.47e-01, error(valid)=8.80e-01, acc(valid)=7.40e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 5: 3.1s to complete
#     error(train)=8.19e-01, acc(train)=7.53e-01, error(valid)=8.48e-01, acc(valid)=7.44e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 6: 3.5s to complete
#     error(train)=7.78e-01, acc(train)=7.64e-01, error(valid)=8.12e-01, acc(valid)=7.56e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 7: 2.8s to complete
#     error(train)=7.65e-01, acc(train)=7.66e-01, error(valid)=8.06e-01, acc(valid)=7.55e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 8: 2.8s to complete
#     error(train)=7.25e-01, acc(train)=7.76e-01, error(valid)=7.63e-01, acc(valid)=7.66e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 9: 3.3s to complete
#     error(train)=7.09e-01, acc(train)=7.81e-01, error(valid)=7.58e-01, acc(valid)=7.70e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 10: 2.8s to complete
#     error(train)=6.95e-01, acc(train)=7.85e-01, error(valid)=7.45e-01, acc(valid)=7.73e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 11: 3.3s to complete
#     error(train)=6.90e-01, acc(train)=7.86e-01, error(valid)=7.44e-01, acc(valid)=7.72e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 12: 3.1s to complete
#     error(train)=6.65e-01, acc(train)=7.92e-01, error(valid)=7.19e-01, acc(valid)=7.79e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 13: 7.2s to complete
#     error(train)=6.68e-01, acc(train)=7.90e-01, error(valid)=7.28e-01, acc(valid)=7.72e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 14: 2.6s to complete
#     error(train)=6.47e-01, acc(train)=7.98e-01, error(valid)=7.12e-01, acc(valid)=7.81e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 15: 2.7s to complete
#     error(train)=6.47e-01, acc(train)=7.95e-01, error(valid)=7.13e-01, acc(valid)=7.83e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 16: 2.4s to complete
#     error(train)=6.33e-01, acc(train)=8.00e-01, error(valid)=7.04e-01, acc(valid)=7.83e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 17: 3.4s to complete
#     error(train)=6.28e-01, acc(train)=8.02e-01, error(valid)=7.03e-01, acc(valid)=7.84e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 18: 3.3s to complete
#     error(train)=6.24e-01, acc(train)=8.03e-01, error(valid)=6.97e-01, acc(valid)=7.88e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 19: 2.5s to complete
#     error(train)=6.18e-01, acc(train)=8.03e-01, error(valid)=6.92e-01, acc(valid)=7.84e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 20: 2.7s to complete
#     error(train)=6.02e-01, acc(train)=8.09e-01, error(valid)=6.80e-01, acc(valid)=7.90e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 21: 2.8s to complete
#     error(train)=6.04e-01, acc(train)=8.09e-01, error(valid)=6.79e-01, acc(valid)=7.90e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 22: 2.4s to complete
#     error(train)=5.97e-01, acc(train)=8.10e-01, error(valid)=6.82e-01, acc(valid)=7.85e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 23: 2.8s to complete
#     error(train)=5.91e-01, acc(train)=8.10e-01, error(valid)=6.76e-01, acc(valid)=7.87e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 24: 2.4s to complete
#     error(train)=6.12e-01, acc(train)=8.04e-01, error(valid)=6.98e-01, acc(valid)=7.82e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 25: 2.5s to complete
#     error(train)=5.84e-01, acc(train)=8.15e-01, error(valid)=6.73e-01, acc(valid)=7.93e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 26: 2.5s to complete
#     error(train)=5.78e-01, acc(train)=8.17e-01, error(valid)=6.69e-01, acc(valid)=7.92e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 27: 2.8s to complete
#     error(train)=5.78e-01, acc(train)=8.15e-01, error(valid)=6.65e-01, acc(valid)=7.89e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 28: 4.2s to complete
#     error(train)=5.74e-01, acc(train)=8.15e-01, error(valid)=6.63e-01, acc(valid)=7.91e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 29: 2.6s to complete
#     error(train)=5.76e-01, acc(train)=8.14e-01, error(valid)=6.68e-01, acc(valid)=7.88e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 30: 3.0s to complete
#     error(train)=5.73e-01, acc(train)=8.16e-01, error(valid)=6.74e-01, acc(valid)=7.89e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 31: 2.5s to complete
#     error(train)=5.73e-01, acc(train)=8.16e-01, error(valid)=6.71e-01, acc(valid)=7.92e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 32: 3.7s to complete
#     error(train)=5.60e-01, acc(train)=8.20e-01, error(valid)=6.59e-01, acc(valid)=7.94e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 33: 3.0s to complete
#     error(train)=5.63e-01, acc(train)=8.18e-01, error(valid)=6.71e-01, acc(valid)=7.89e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 34: 2.5s to complete
#     error(train)=5.59e-01, acc(train)=8.20e-01, error(valid)=6.61e-01, acc(valid)=7.93e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 35: 3.3s to complete
#     error(train)=5.66e-01, acc(train)=8.13e-01, error(valid)=6.71e-01, acc(valid)=7.90e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 36: 2.6s to complete
#     error(train)=5.59e-01, acc(train)=8.18e-01, error(valid)=6.66e-01, acc(valid)=7.93e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 37: 2.7s to complete
#     error(train)=5.49e-01, acc(train)=8.21e-01, error(valid)=6.56e-01, acc(valid)=7.92e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 38: 3.0s to complete
#     error(train)=5.35e-01, acc(train)=8.27e-01, error(valid)=6.40e-01, acc(valid)=8.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 39: 2.7s to complete
#     error(train)=5.59e-01, acc(train)=8.19e-01, error(valid)=6.74e-01, acc(valid)=7.91e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 40: 2.4s to complete
#     error(train)=5.44e-01, acc(train)=8.24e-01, error(valid)=6.54e-01, acc(valid)=7.96e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 41: 2.5s to complete
#     error(train)=5.35e-01, acc(train)=8.26e-01, error(valid)=6.49e-01, acc(valid)=7.95e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 42: 3.6s to complete
#     error(train)=5.41e-01, acc(train)=8.25e-01, error(valid)=6.60e-01, acc(valid)=7.94e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 43: 2.5s to complete
#     error(train)=5.48e-01, acc(train)=8.19e-01, error(valid)=6.63e-01, acc(valid)=7.91e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 44: 2.7s to complete
#     error(train)=5.42e-01, acc(train)=8.22e-01, error(valid)=6.56e-01, acc(valid)=7.95e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 45: 2.5s to complete
#     error(train)=5.37e-01, acc(train)=8.24e-01, error(valid)=6.54e-01, acc(valid)=7.98e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 46: 2.5s to complete
#     error(train)=5.26e-01, acc(train)=8.28e-01, error(valid)=6.43e-01, acc(valid)=7.99e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 47: 2.5s to complete
#     error(train)=5.22e-01, acc(train)=8.30e-01, error(valid)=6.43e-01, acc(valid)=8.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 48: 2.4s to complete
#     error(train)=5.24e-01, acc(train)=8.28e-01, error(valid)=6.42e-01, acc(valid)=8.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 49: 2.5s to complete
#     error(train)=5.21e-01, acc(train)=8.30e-01, error(valid)=6.42e-01, acc(valid)=8.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 50: 3.0s to complete
#     error(train)=5.21e-01, acc(train)=8.29e-01, error(valid)=6.48e-01, acc(valid)=7.98e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 51: 2.4s to complete
#     error(train)=5.23e-01, acc(train)=8.28e-01, error(valid)=6.47e-01, acc(valid)=7.96e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 52: 2.5s to complete
#     error(train)=5.23e-01, acc(train)=8.28e-01, error(valid)=6.48e-01, acc(valid)=7.99e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 53: 2.6s to complete
#     error(train)=5.18e-01, acc(train)=8.28e-01, error(valid)=6.47e-01, acc(valid)=7.95e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 54: 2.9s to complete
#     error(train)=5.28e-01, acc(train)=8.28e-01, error(valid)=6.55e-01, acc(valid)=7.97e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 55: 2.4s to complete
#     error(train)=5.17e-01, acc(train)=8.29e-01, error(valid)=6.46e-01, acc(valid)=7.97e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 56: 2.4s to complete
#     error(train)=5.27e-01, acc(train)=8.26e-01, error(valid)=6.59e-01, acc(valid)=7.92e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 57: 2.5s to complete
#     error(train)=5.14e-01, acc(train)=8.28e-01, error(valid)=6.44e-01, acc(valid)=7.96e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 58: 2.6s to complete
#     error(train)=5.10e-01, acc(train)=8.33e-01, error(valid)=6.40e-01, acc(valid)=8.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 59: 2.6s to complete
#     error(train)=5.21e-01, acc(train)=8.28e-01, error(valid)=6.58e-01, acc(valid)=7.95e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 60: 2.5s to complete
#     error(train)=5.26e-01, acc(train)=8.25e-01, error(valid)=6.61e-01, acc(valid)=7.92e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 61: 2.5s to complete
#     error(train)=5.02e-01, acc(train)=8.35e-01, error(valid)=6.38e-01, acc(valid)=8.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 62: 2.8s to complete
#     error(train)=5.03e-01, acc(train)=8.34e-01, error(valid)=6.36e-01, acc(valid)=8.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 63: 2.7s to complete
#     error(train)=5.04e-01, acc(train)=8.33e-01, error(valid)=6.43e-01, acc(valid)=8.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 64: 2.6s to complete
#     error(train)=5.09e-01, acc(train)=8.32e-01, error(valid)=6.49e-01, acc(valid)=7.97e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 65: 2.4s to complete
#     error(train)=5.00e-01, acc(train)=8.36e-01, error(valid)=6.44e-01, acc(valid)=8.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 66: 2.4s to complete
#     error(train)=5.02e-01, acc(train)=8.35e-01, error(valid)=6.41e-01, acc(valid)=8.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 67: 2.7s to complete
#     error(train)=4.99e-01, acc(train)=8.34e-01, error(valid)=6.44e-01, acc(valid)=7.97e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 68: 2.9s to complete
#     error(train)=5.07e-01, acc(train)=8.32e-01, error(valid)=6.56e-01, acc(valid)=7.95e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 69: 2.6s to complete
#     error(train)=5.09e-01, acc(train)=8.30e-01, error(valid)=6.55e-01, acc(valid)=7.92e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 70: 2.5s to complete
#     error(train)=5.04e-01, acc(train)=8.32e-01, error(valid)=6.53e-01, acc(valid)=7.92e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 71: 4.7s to complete
#     error(train)=4.97e-01, acc(train)=8.37e-01, error(valid)=6.44e-01, acc(valid)=8.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 72: 3.1s to complete
#     error(train)=5.05e-01, acc(train)=8.32e-01, error(valid)=6.53e-01, acc(valid)=7.97e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 73: 2.5s to complete
#     error(train)=5.06e-01, acc(train)=8.32e-01, error(valid)=6.59e-01, acc(valid)=7.95e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 74: 3.4s to complete
#     error(train)=4.97e-01, acc(train)=8.35e-01, error(valid)=6.51e-01, acc(valid)=7.97e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 75: 3.4s to complete
#     error(train)=4.97e-01, acc(train)=8.36e-01, error(valid)=6.49e-01, acc(valid)=8.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 76: 2.7s to complete
#     error(train)=4.89e-01, acc(train)=8.39e-01, error(valid)=6.45e-01, acc(valid)=8.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 77: 2.5s to complete
#     error(train)=4.88e-01, acc(train)=8.37e-01, error(valid)=6.43e-01, acc(valid)=8.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 78: 2.6s to complete
#     error(train)=4.94e-01, acc(train)=8.36e-01, error(valid)=6.49e-01, acc(valid)=7.99e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 79: 2.8s to complete
#     error(train)=4.84e-01, acc(train)=8.40e-01, error(valid)=6.36e-01, acc(valid)=8.03e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 80: 4.0s to complete
#     error(train)=4.89e-01, acc(train)=8.37e-01, error(valid)=6.49e-01, acc(valid)=7.99e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 81: 3.3s to complete
#     error(train)=4.81e-01, acc(train)=8.41e-01, error(valid)=6.44e-01, acc(valid)=8.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 82: 3.7s to complete
#     error(train)=4.88e-01, acc(train)=8.38e-01, error(valid)=6.45e-01, acc(valid)=8.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 83: 2.8s to complete
#     error(train)=4.93e-01, acc(train)=8.35e-01, error(valid)=6.53e-01, acc(valid)=7.95e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 84: 2.7s to complete
#     error(train)=4.87e-01, acc(train)=8.38e-01, error(valid)=6.50e-01, acc(valid)=8.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 85: 2.6s to complete
#     error(train)=4.89e-01, acc(train)=8.36e-01, error(valid)=6.52e-01, acc(valid)=7.96e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 86: 2.6s to complete
#     error(train)=4.92e-01, acc(train)=8.36e-01, error(valid)=6.60e-01, acc(valid)=7.98e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 87: 3.5s to complete
#     error(train)=4.91e-01, acc(train)=8.36e-01, error(valid)=6.56e-01, acc(valid)=7.94e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 88: 4.5s to complete
#     error(train)=4.80e-01, acc(train)=8.39e-01, error(valid)=6.50e-01, acc(valid)=7.99e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 89: 4.3s to complete
#     error(train)=4.78e-01, acc(train)=8.41e-01, error(valid)=6.49e-01, acc(valid)=7.99e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 90: 2.7s to complete
#     error(train)=4.83e-01, acc(train)=8.39e-01, error(valid)=6.55e-01, acc(valid)=7.99e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 91: 3.3s to complete
#     error(train)=4.78e-01, acc(train)=8.42e-01, error(valid)=6.47e-01, acc(valid)=8.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 92: 3.3s to complete
#     error(train)=4.87e-01, acc(train)=8.36e-01, error(valid)=6.64e-01, acc(valid)=7.96e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 93: 4.6s to complete
#     error(train)=4.90e-01, acc(train)=8.35e-01, error(valid)=6.63e-01, acc(valid)=7.96e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 94: 4.0s to complete
#     error(train)=4.78e-01, acc(train)=8.41e-01, error(valid)=6.58e-01, acc(valid)=8.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 95: 3.7s to complete
#     error(train)=4.80e-01, acc(train)=8.40e-01, error(valid)=6.55e-01, acc(valid)=7.96e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 96: 5.6s to complete
#     error(train)=4.85e-01, acc(train)=8.39e-01, error(valid)=6.64e-01, acc(valid)=7.99e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 97: 6.4s to complete
#     error(train)=4.77e-01, acc(train)=8.41e-01, error(valid)=6.55e-01, acc(valid)=7.99e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 98: 6.6s to complete
#     error(train)=4.77e-01, acc(train)=8.41e-01, error(valid)=6.55e-01, acc(valid)=7.99e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 99: 9.2s to complete
#     error(train)=4.74e-01, acc(train)=8.41e-01, error(valid)=6.54e-01, acc(valid)=8.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 100: 7.2s to complete
#     error(train)=4.77e-01, acc(train)=8.40e-01, error(valid)=6.58e-01, acc(valid)=7.98e-01
# OrderedDict([('error(test)', 0.7023555182383711), ('acc(test)', 0.7868987341772153)])

# %%
def evaluation(dataset,model):
    for inputs,targets in dataset:
        predictions = model.fprop(inputs,evaluation = True)[-1]
        accuracy = (predictions.argmax(-1) == targets.argmax(-1))
    return accuracy

test_acc = evaluation(test_data,model)
test_acc

# %%
error_valid= stats_u32_h2[1:, keys['error(valid)']]
error_train= stats_u32_h2[1:, keys['error(train)']]
acc_valid = stats_u32_h2[1:, keys['acc(valid)']]
print('Best accuracy at Epoch={} by learning_rate={}, acc(valid)={}'.
      format(np.argmax(acc_valid)+1,learning_rate, max(acc_valid)))

# %%
error_valid= stats_u32_h2[1:, keys['error(valid)']]
error_train= stats_u32_h2[1:, keys['error(train)']]
acc_valid = stats_u32_h2[1:, keys['acc(valid)']]
print('Best accuracy at Epoch={} by learning_rate={}, acc(valid)={}'.
      format(np.argmax(acc_valid)+1,learning_rate, max(acc_valid)))

# %%
error_valid= stats_u32_h2[1:, keys['error(valid)']]
error_train= stats_u32_h2[1:, keys['error(train)']]
acc_valid = stats_u32_h2[1:, keys['acc(valid)']]
print('Best accuracy at Epoch={} by learning_rate={}, acc(valid)={}'.
      format(np.argmax(acc_valid)+1,learning_rate, max(acc_valid)))

# %% [markdown]
# ### hidden units 64, hidden layers 2

# %%
#Base Line ReLu
# Reset random number generator and data provider states on each run
# to ensure reproducibility of results
rng.seed(seed)
train_data.reset()
valid_data.reset()
#setup hyperparameters
learning_rate = 0.01
num_epochs = 100
stats_interval = 1
input_dim, output_dim = 784, 47
hidden_dim = 64

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule()

#Remember to use notebook=False when you write a script to be run in a terminal
#return stats, keys, run_time, fig_1, ax_1, fig_2, ax_2
_= train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 1: 10.8s to complete
#     error(train)=9.28e-01, acc(train)=7.27e-01, error(valid)=9.42e-01, acc(valid)=7.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 2: 10.6s to complete
#     error(train)=7.42e-01, acc(train)=7.73e-01, error(valid)=7.68e-01, acc(valid)=7.66e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 3: 8.9s to complete
#     error(train)=6.56e-01, acc(train)=7.93e-01, error(valid)=6.91e-01, acc(valid)=7.84e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 4: 9.1s to complete
#     error(train)=5.99e-01, acc(train)=8.09e-01, error(valid)=6.47e-01, acc(valid)=7.95e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 5: 11.5s to complete
#     error(train)=5.82e-01, acc(train)=8.10e-01, error(valid)=6.35e-01, acc(valid)=7.97e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 6: 8.4s to complete
#     error(train)=5.48e-01, acc(train)=8.21e-01, error(valid)=6.08e-01, acc(valid)=8.07e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 7: 9.7s to complete
#     error(train)=5.24e-01, acc(train)=8.29e-01, error(valid)=5.95e-01, acc(valid)=8.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 8: 8.6s to complete
#     error(train)=4.99e-01, acc(train)=8.37e-01, error(valid)=5.79e-01, acc(valid)=8.13e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 9: 10.0s to complete
#     error(train)=4.93e-01, acc(train)=8.36e-01, error(valid)=5.76e-01, acc(valid)=8.15e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 10: 8.7s to complete
#     error(train)=4.70e-01, acc(train)=8.46e-01, error(valid)=5.65e-01, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 11: 10.3s to complete
#     error(train)=4.48e-01, acc(train)=8.52e-01, error(valid)=5.48e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 12: 9.1s to complete
#     error(train)=4.57e-01, acc(train)=8.48e-01, error(valid)=5.70e-01, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 13: 10.0s to complete
#     error(train)=4.43e-01, acc(train)=8.50e-01, error(valid)=5.56e-01, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 14: 8.9s to complete
#     error(train)=4.34e-01, acc(train)=8.53e-01, error(valid)=5.57e-01, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 15: 9.5s to complete
#     error(train)=4.21e-01, acc(train)=8.57e-01, error(valid)=5.50e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 16: 9.1s to complete
#     error(train)=4.15e-01, acc(train)=8.60e-01, error(valid)=5.54e-01, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 17: 9.7s to complete
#     error(train)=4.11e-01, acc(train)=8.58e-01, error(valid)=5.49e-01, acc(valid)=8.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 18: 9.4s to complete
#     error(train)=4.02e-01, acc(train)=8.63e-01, error(valid)=5.48e-01, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 19: 10.0s to complete
#     error(train)=3.98e-01, acc(train)=8.64e-01, error(valid)=5.56e-01, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 20: 9.7s to complete
#     error(train)=4.11e-01, acc(train)=8.58e-01, error(valid)=5.66e-01, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 21: 11.1s to complete
#     error(train)=3.95e-01, acc(train)=8.62e-01, error(valid)=5.57e-01, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 22: 9.5s to complete
#     error(train)=3.96e-01, acc(train)=8.63e-01, error(valid)=5.58e-01, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 23: 9.4s to complete
#     error(train)=3.89e-01, acc(train)=8.65e-01, error(valid)=5.59e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 24: 9.4s to complete
#     error(train)=3.72e-01, acc(train)=8.71e-01, error(valid)=5.50e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 25: 13.9s to complete
#     error(train)=3.71e-01, acc(train)=8.68e-01, error(valid)=5.56e-01, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 26: 10.2s to complete
#     error(train)=3.71e-01, acc(train)=8.71e-01, error(valid)=5.59e-01, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 27: 9.8s to complete
#     error(train)=3.79e-01, acc(train)=8.67e-01, error(valid)=5.72e-01, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 28: 10.2s to complete
#     error(train)=3.61e-01, acc(train)=8.73e-01, error(valid)=5.59e-01, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 29: 10.2s to complete
#     error(train)=3.53e-01, acc(train)=8.76e-01, error(valid)=5.54e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 30: 10.0s to complete
#     error(train)=3.55e-01, acc(train)=8.75e-01, error(valid)=5.58e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 31: 12.1s to complete
#     error(train)=3.55e-01, acc(train)=8.75e-01, error(valid)=5.66e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 32: 13.2s to complete
#     error(train)=3.60e-01, acc(train)=8.71e-01, error(valid)=5.76e-01, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 33: 10.0s to complete
#     error(train)=3.38e-01, acc(train)=8.80e-01, error(valid)=5.54e-01, acc(valid)=8.30e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 34: 10.2s to complete
#     error(train)=3.42e-01, acc(train)=8.78e-01, error(valid)=5.57e-01, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 35: 12.9s to complete
#     error(train)=3.36e-01, acc(train)=8.81e-01, error(valid)=5.63e-01, acc(valid)=8.29e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 36: 12.5s to complete
#     error(train)=3.54e-01, acc(train)=8.73e-01, error(valid)=5.84e-01, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 37: 11.8s to complete
#     error(train)=3.36e-01, acc(train)=8.79e-01, error(valid)=5.77e-01, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 38: 9.9s to complete
#     error(train)=3.30e-01, acc(train)=8.80e-01, error(valid)=5.75e-01, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 39: 10.2s to complete
#     error(train)=3.42e-01, acc(train)=8.77e-01, error(valid)=5.92e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 40: 10.7s to complete
#     error(train)=3.24e-01, acc(train)=8.84e-01, error(valid)=5.73e-01, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 41: 10.8s to complete
#     error(train)=3.20e-01, acc(train)=8.86e-01, error(valid)=5.71e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 42: 11.5s to complete
#     error(train)=3.21e-01, acc(train)=8.85e-01, error(valid)=5.82e-01, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 43: 10.7s to complete
#     error(train)=3.22e-01, acc(train)=8.83e-01, error(valid)=5.90e-01, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 44: 10.1s to complete
#     error(train)=3.19e-01, acc(train)=8.84e-01, error(valid)=5.86e-01, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 45: 10.1s to complete
#     error(train)=3.20e-01, acc(train)=8.83e-01, error(valid)=5.92e-01, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 46: 10.3s to complete
#     error(train)=3.19e-01, acc(train)=8.85e-01, error(valid)=5.92e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 47: 10.1s to complete
#     error(train)=3.08e-01, acc(train)=8.88e-01, error(valid)=5.91e-01, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 48: 10.3s to complete
#     error(train)=3.14e-01, acc(train)=8.86e-01, error(valid)=5.95e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 49: 10.1s to complete
#     error(train)=3.16e-01, acc(train)=8.85e-01, error(valid)=6.06e-01, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 50: 10.5s to complete
#     error(train)=3.12e-01, acc(train)=8.87e-01, error(valid)=6.06e-01, acc(valid)=8.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 51: 10.0s to complete
#     error(train)=3.12e-01, acc(train)=8.86e-01, error(valid)=6.12e-01, acc(valid)=8.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 52: 10.3s to complete
#     error(train)=3.13e-01, acc(train)=8.85e-01, error(valid)=6.16e-01, acc(valid)=8.17e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 53: 10.7s to complete
#     error(train)=3.03e-01, acc(train)=8.89e-01, error(valid)=6.11e-01, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 54: 10.3s to complete
#     error(train)=3.06e-01, acc(train)=8.87e-01, error(valid)=6.17e-01, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 55: 10.5s to complete
#     error(train)=3.06e-01, acc(train)=8.87e-01, error(valid)=6.20e-01, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 56: 9.9s to complete
#     error(train)=2.99e-01, acc(train)=8.90e-01, error(valid)=6.16e-01, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 57: 10.1s to complete
#     error(train)=2.95e-01, acc(train)=8.93e-01, error(valid)=6.14e-01, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 58: 10.9s to complete
#     error(train)=2.95e-01, acc(train)=8.90e-01, error(valid)=6.29e-01, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 59: 10.9s to complete
#     error(train)=3.10e-01, acc(train)=8.86e-01, error(valid)=6.40e-01, acc(valid)=8.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 60: 10.1s to complete
#     error(train)=2.99e-01, acc(train)=8.89e-01, error(valid)=6.43e-01, acc(valid)=8.17e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 61: 10.2s to complete
#     error(train)=2.90e-01, acc(train)=8.93e-01, error(valid)=6.29e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 62: 9.8s to complete
#     error(train)=2.88e-01, acc(train)=8.93e-01, error(valid)=6.44e-01, acc(valid)=8.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 63: 9.9s to complete
#     error(train)=2.85e-01, acc(train)=8.94e-01, error(valid)=6.42e-01, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 64: 9.8s to complete
#     error(train)=2.96e-01, acc(train)=8.89e-01, error(valid)=6.52e-01, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 65: 12.5s to complete
#     error(train)=2.89e-01, acc(train)=8.93e-01, error(valid)=6.56e-01, acc(valid)=8.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 66: 10.0s to complete
#     error(train)=2.92e-01, acc(train)=8.91e-01, error(valid)=6.57e-01, acc(valid)=8.17e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 67: 10.0s to complete
#     error(train)=2.83e-01, acc(train)=8.96e-01, error(valid)=6.44e-01, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 68: 10.1s to complete
#     error(train)=2.86e-01, acc(train)=8.93e-01, error(valid)=6.60e-01, acc(valid)=8.14e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 69: 11.7s to complete
#     error(train)=2.77e-01, acc(train)=8.98e-01, error(valid)=6.48e-01, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 70: 10.3s to complete
#     error(train)=2.88e-01, acc(train)=8.92e-01, error(valid)=6.58e-01, acc(valid)=8.15e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 71: 10.5s to complete
#     error(train)=2.90e-01, acc(train)=8.92e-01, error(valid)=6.66e-01, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 72: 9.9s to complete
#     error(train)=2.80e-01, acc(train)=8.95e-01, error(valid)=6.64e-01, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 73: 11.1s to complete
#     error(train)=2.86e-01, acc(train)=8.92e-01, error(valid)=6.86e-01, acc(valid)=8.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 74: 9.9s to complete
#     error(train)=2.79e-01, acc(train)=8.96e-01, error(valid)=6.70e-01, acc(valid)=8.17e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 75: 10.4s to complete
#     error(train)=2.72e-01, acc(train)=8.99e-01, error(valid)=6.75e-01, acc(valid)=8.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 76: 10.8s to complete
#     error(train)=2.79e-01, acc(train)=8.96e-01, error(valid)=6.82e-01, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 77: 10.8s to complete
#     error(train)=2.71e-01, acc(train)=8.99e-01, error(valid)=6.88e-01, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 78: 10.1s to complete
#     error(train)=2.72e-01, acc(train)=8.98e-01, error(valid)=6.86e-01, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 79: 11.5s to complete
#     error(train)=2.68e-01, acc(train)=9.00e-01, error(valid)=6.80e-01, acc(valid)=8.17e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 80: 12.6s to complete
#     error(train)=2.78e-01, acc(train)=8.93e-01, error(valid)=6.98e-01, acc(valid)=8.11e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 81: 10.9s to complete
#     error(train)=2.74e-01, acc(train)=8.98e-01, error(valid)=7.05e-01, acc(valid)=8.15e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 82: 10.0s to complete
#     error(train)=2.66e-01, acc(train)=9.00e-01, error(valid)=6.90e-01, acc(valid)=8.17e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 83: 13.0s to complete
#     error(train)=2.67e-01, acc(train)=9.00e-01, error(valid)=7.02e-01, acc(valid)=8.13e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 84: 10.3s to complete
#     error(train)=2.71e-01, acc(train)=8.98e-01, error(valid)=6.93e-01, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 85: 10.0s to complete
#     error(train)=2.64e-01, acc(train)=8.99e-01, error(valid)=7.05e-01, acc(valid)=8.14e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 86: 10.4s to complete
#     error(train)=2.70e-01, acc(train)=8.98e-01, error(valid)=7.19e-01, acc(valid)=8.13e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 87: 10.8s to complete
#     error(train)=2.74e-01, acc(train)=8.97e-01, error(valid)=7.18e-01, acc(valid)=8.13e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 88: 10.7s to complete
#     error(train)=2.66e-01, acc(train)=9.00e-01, error(valid)=7.16e-01, acc(valid)=8.15e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 89: 14.0s to complete
#     error(train)=2.68e-01, acc(train)=8.98e-01, error(valid)=7.36e-01, acc(valid)=8.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 90: 12.8s to complete
#     error(train)=2.64e-01, acc(train)=9.00e-01, error(valid)=7.23e-01, acc(valid)=8.13e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 91: 13.1s to complete
#     error(train)=2.65e-01, acc(train)=8.99e-01, error(valid)=7.37e-01, acc(valid)=8.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 92: 12.3s to complete
#     error(train)=2.53e-01, acc(train)=9.05e-01, error(valid)=7.21e-01, acc(valid)=8.15e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 93: 23.6s to complete
#     error(train)=2.58e-01, acc(train)=9.03e-01, error(valid)=7.29e-01, acc(valid)=8.13e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 94: 42.7s to complete
#     error(train)=2.70e-01, acc(train)=8.96e-01, error(valid)=7.62e-01, acc(valid)=8.09e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 95: 14.0s to complete
#     error(train)=2.54e-01, acc(train)=9.04e-01, error(valid)=7.32e-01, acc(valid)=8.10e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 96: 12.3s to complete
#     error(train)=2.57e-01, acc(train)=9.03e-01, error(valid)=7.44e-01, acc(valid)=8.09e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 97: 12.6s to complete
#     error(train)=2.63e-01, acc(train)=9.00e-01, error(valid)=7.54e-01, acc(valid)=8.11e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 98: 11.2s to complete
#     error(train)=2.58e-01, acc(train)=9.02e-01, error(valid)=7.52e-01, acc(valid)=8.10e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 99: 11.2s to complete
#     error(train)=2.51e-01, acc(train)=9.05e-01, error(valid)=7.53e-01, acc(valid)=8.14e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 100: 11.0s to complete
#     error(train)=2.57e-01, acc(train)=9.02e-01, error(valid)=7.68e-01, acc(valid)=8.13e-01
# OrderedDict([('error(test)', 0.8053418068317283), ('acc(test)', 0.8058227848101267)])

# %% [markdown]
# ### hidden units 128, hidden layers 2

# %%
#Base Line ReLu
# Reset random number generator and data provider states on each run
# to ensure reproducibility of results
rng.seed(seed)
train_data.reset()
valid_data.reset()
#setup hyperparameters
learning_rate = 0.01
num_epochs = 100
stats_interval = 1
input_dim, output_dim = 784, 47
hidden_dim = 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule()

#Remember to use notebook=False when you write a script to be run in a terminal
#return stats, keys, run_time, fig_1, ax_1, fig_2, ax_2
_= train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 1: 27.8s to complete
#     error(train)=7.57e-01, acc(train)=7.72e-01, error(valid)=7.76e-01, acc(valid)=7.65e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 2: 28.6s to complete
#     error(train)=5.94e-01, acc(train)=8.14e-01, error(valid)=6.37e-01, acc(valid)=7.99e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 3: 22.8s to complete
#     error(train)=5.20e-01, acc(train)=8.30e-01, error(valid)=5.76e-01, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 4: 25.8s to complete
#     error(train)=4.77e-01, acc(train)=8.40e-01, error(valid)=5.56e-01, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 5: 22.1s to complete
#     error(train)=4.29e-01, acc(train)=8.54e-01, error(valid)=5.19e-01, acc(valid)=8.30e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 6: 20.6s to complete
#     error(train)=4.05e-01, acc(train)=8.62e-01, error(valid)=5.07e-01, acc(valid)=8.33e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 7: 24.2s to complete
#     error(train)=3.91e-01, acc(train)=8.62e-01, error(valid)=5.10e-01, acc(valid)=8.29e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 8: 22.4s to complete
#     error(train)=3.77e-01, acc(train)=8.66e-01, error(valid)=5.11e-01, acc(valid)=8.30e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 9: 30.5s to complete
#     error(train)=3.50e-01, acc(train)=8.75e-01, error(valid)=4.98e-01, acc(valid)=8.37e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 10: 30.2s to complete
#     error(train)=3.42e-01, acc(train)=8.77e-01, error(valid)=5.05e-01, acc(valid)=8.37e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 11: 24.7s to complete
#     error(train)=3.16e-01, acc(train)=8.84e-01, error(valid)=4.92e-01, acc(valid)=8.39e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 12: 41.6s to complete
#     error(train)=3.08e-01, acc(train)=8.85e-01, error(valid)=4.98e-01, acc(valid)=8.38e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 13: 34.3s to complete
#     error(train)=2.99e-01, acc(train)=8.90e-01, error(valid)=4.97e-01, acc(valid)=8.37e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 14: 38.9s to complete
#     error(train)=2.86e-01, acc(train)=8.94e-01, error(valid)=5.01e-01, acc(valid)=8.42e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 15: 32.2s to complete
#     error(train)=2.85e-01, acc(train)=8.93e-01, error(valid)=5.14e-01, acc(valid)=8.42e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 16: 50.5s to complete
#     error(train)=2.66e-01, acc(train)=8.99e-01, error(valid)=5.07e-01, acc(valid)=8.42e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 17: 45.1s to complete
#     error(train)=2.53e-01, acc(train)=9.04e-01, error(valid)=5.15e-01, acc(valid)=8.43e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 18: 30.4s to complete
#     error(train)=2.68e-01, acc(train)=8.97e-01, error(valid)=5.42e-01, acc(valid)=8.36e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 19: 25.9s to complete
#     error(train)=2.52e-01, acc(train)=9.04e-01, error(valid)=5.41e-01, acc(valid)=8.35e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 20: 35.3s to complete
#     error(train)=2.30e-01, acc(train)=9.12e-01, error(valid)=5.35e-01, acc(valid)=8.39e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 21: 21.9s to complete
#     error(train)=2.36e-01, acc(train)=9.09e-01, error(valid)=5.43e-01, acc(valid)=8.39e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 22: 17.9s to complete
#     error(train)=2.27e-01, acc(train)=9.12e-01, error(valid)=5.60e-01, acc(valid)=8.41e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 23: 16.9s to complete
#     error(train)=2.15e-01, acc(train)=9.16e-01, error(valid)=5.62e-01, acc(valid)=8.41e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 24: 17.5s to complete
#     error(train)=2.09e-01, acc(train)=9.18e-01, error(valid)=5.65e-01, acc(valid)=8.40e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 25: 16.8s to complete
#     error(train)=2.14e-01, acc(train)=9.15e-01, error(valid)=5.81e-01, acc(valid)=8.36e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 26: 17.5s to complete
#     error(train)=2.08e-01, acc(train)=9.18e-01, error(valid)=5.86e-01, acc(valid)=8.35e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 27: 17.7s to complete
#     error(train)=2.09e-01, acc(train)=9.17e-01, error(valid)=6.08e-01, acc(valid)=8.36e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 28: 18.2s to complete
#     error(train)=2.04e-01, acc(train)=9.20e-01, error(valid)=6.17e-01, acc(valid)=8.36e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 29: 20.8s to complete
#     error(train)=1.97e-01, acc(train)=9.21e-01, error(valid)=6.40e-01, acc(valid)=8.35e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 30: 21.2s to complete
#     error(train)=1.93e-01, acc(train)=9.22e-01, error(valid)=6.46e-01, acc(valid)=8.29e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 31: 20.5s to complete
#     error(train)=1.85e-01, acc(train)=9.25e-01, error(valid)=6.52e-01, acc(valid)=8.32e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 32: 24.2s to complete
#     error(train)=1.81e-01, acc(train)=9.27e-01, error(valid)=6.53e-01, acc(valid)=8.33e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 33: 20.3s to complete
#     error(train)=1.84e-01, acc(train)=9.25e-01, error(valid)=6.88e-01, acc(valid)=8.29e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 34: 21.5s to complete
#     error(train)=1.79e-01, acc(train)=9.28e-01, error(valid)=6.89e-01, acc(valid)=8.32e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 35: 20.7s to complete
#     error(train)=1.75e-01, acc(train)=9.29e-01, error(valid)=7.03e-01, acc(valid)=8.34e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 36: 21.5s to complete
#     error(train)=1.77e-01, acc(train)=9.29e-01, error(valid)=7.20e-01, acc(valid)=8.30e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 37: 20.3s to complete
#     error(train)=1.72e-01, acc(train)=9.31e-01, error(valid)=7.27e-01, acc(valid)=8.30e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 38: 21.6s to complete
#     error(train)=1.69e-01, acc(train)=9.31e-01, error(valid)=7.38e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 39: 20.9s to complete
#     error(train)=1.65e-01, acc(train)=9.33e-01, error(valid)=7.46e-01, acc(valid)=8.31e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 40: 20.3s to complete
#     error(train)=1.61e-01, acc(train)=9.34e-01, error(valid)=7.66e-01, acc(valid)=8.32e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 41: 21.3s to complete
#     error(train)=1.66e-01, acc(train)=9.33e-01, error(valid)=7.96e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 42: 24.2s to complete
#     error(train)=1.58e-01, acc(train)=9.35e-01, error(valid)=8.03e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 43: 20.4s to complete
#     error(train)=1.54e-01, acc(train)=9.37e-01, error(valid)=8.18e-01, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 44: 19.9s to complete
#     error(train)=1.55e-01, acc(train)=9.37e-01, error(valid)=8.22e-01, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 45: 27.1s to complete
#     error(train)=1.55e-01, acc(train)=9.35e-01, error(valid)=8.37e-01, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 46: 20.8s to complete
#     error(train)=1.41e-01, acc(train)=9.42e-01, error(valid)=8.36e-01, acc(valid)=8.30e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 47: 20.4s to complete
#     error(train)=1.51e-01, acc(train)=9.37e-01, error(valid)=8.65e-01, acc(valid)=8.27e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 48: 20.0s to complete
#     error(train)=1.43e-01, acc(train)=9.41e-01, error(valid)=8.63e-01, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 49: 20.8s to complete
#     error(train)=1.40e-01, acc(train)=9.43e-01, error(valid)=8.66e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 50: 24.3s to complete
#     error(train)=1.43e-01, acc(train)=9.42e-01, error(valid)=9.06e-01, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 51: 28.1s to complete
#     error(train)=1.37e-01, acc(train)=9.44e-01, error(valid)=8.79e-01, acc(valid)=8.29e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 52: 27.4s to complete
#     error(train)=1.35e-01, acc(train)=9.45e-01, error(valid)=9.27e-01, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 53: 25.3s to complete
#     error(train)=1.40e-01, acc(train)=9.41e-01, error(valid)=9.39e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 54: 25.4s to complete
#     error(train)=1.35e-01, acc(train)=9.44e-01, error(valid)=9.40e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 55: 25.2s to complete
#     error(train)=1.35e-01, acc(train)=9.44e-01, error(valid)=9.66e-01, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 56: 27.0s to complete
#     error(train)=1.27e-01, acc(train)=9.47e-01, error(valid)=9.62e-01, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 57: 25.4s to complete
#     error(train)=1.36e-01, acc(train)=9.43e-01, error(valid)=9.81e-01, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 58: 26.2s to complete
#     error(train)=1.24e-01, acc(train)=9.49e-01, error(valid)=9.87e-01, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 59: 25.1s to complete
#     error(train)=1.37e-01, acc(train)=9.43e-01, error(valid)=1.02e+00, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 60: 25.1s to complete
#     error(train)=1.32e-01, acc(train)=9.45e-01, error(valid)=1.03e+00, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 61: 30.4s to complete
#     error(train)=1.25e-01, acc(train)=9.48e-01, error(valid)=1.02e+00, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 62: 26.5s to complete
#     error(train)=1.19e-01, acc(train)=9.51e-01, error(valid)=1.02e+00, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 63: 25.4s to complete
#     error(train)=1.42e-01, acc(train)=9.41e-01, error(valid)=1.11e+00, acc(valid)=8.14e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 64: 24.6s to complete
#     error(train)=1.34e-01, acc(train)=9.46e-01, error(valid)=1.10e+00, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 65: 39.5s to complete
#     error(train)=1.20e-01, acc(train)=9.50e-01, error(valid)=1.10e+00, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 66: 26.2s to complete
#     error(train)=1.23e-01, acc(train)=9.47e-01, error(valid)=1.11e+00, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 67: 25.6s to complete
#     error(train)=1.30e-01, acc(train)=9.46e-01, error(valid)=1.13e+00, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 68: 32.2s to complete
#     error(train)=1.16e-01, acc(train)=9.51e-01, error(valid)=1.10e+00, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 69: 25.1s to complete
#     error(train)=1.14e-01, acc(train)=9.53e-01, error(valid)=1.14e+00, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 70: 27.4s to complete
#     error(train)=1.15e-01, acc(train)=9.53e-01, error(valid)=1.16e+00, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 71: 27.6s to complete
#     error(train)=1.13e-01, acc(train)=9.54e-01, error(valid)=1.18e+00, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 72: 25.6s to complete
#     error(train)=1.20e-01, acc(train)=9.50e-01, error(valid)=1.18e+00, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 73: 25.2s to complete
#     error(train)=1.21e-01, acc(train)=9.48e-01, error(valid)=1.21e+00, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 74: 32.5s to complete
#     error(train)=1.05e-01, acc(train)=9.56e-01, error(valid)=1.20e+00, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 75: 26.5s to complete
#     error(train)=1.27e-01, acc(train)=9.48e-01, error(valid)=1.25e+00, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 76: 27.9s to complete
#     error(train)=1.05e-01, acc(train)=9.56e-01, error(valid)=1.21e+00, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 77: 25.6s to complete
#     error(train)=1.20e-01, acc(train)=9.51e-01, error(valid)=1.26e+00, acc(valid)=8.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 78: 25.8s to complete
#     error(train)=1.12e-01, acc(train)=9.54e-01, error(valid)=1.25e+00, acc(valid)=8.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 79: 26.4s to complete
#     error(train)=1.13e-01, acc(train)=9.53e-01, error(valid)=1.27e+00, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 80: 27.2s to complete
#     error(train)=1.07e-01, acc(train)=9.56e-01, error(valid)=1.31e+00, acc(valid)=8.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 81: 26.6s to complete
#     error(train)=1.07e-01, acc(train)=9.57e-01, error(valid)=1.30e+00, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 82: 28.4s to complete
#     error(train)=1.05e-01, acc(train)=9.57e-01, error(valid)=1.32e+00, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 83: 25.2s to complete
#     error(train)=1.21e-01, acc(train)=9.50e-01, error(valid)=1.36e+00, acc(valid)=8.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 84: 25.8s to complete
#     error(train)=1.21e-01, acc(train)=9.51e-01, error(valid)=1.37e+00, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 85: 27.3s to complete
#     error(train)=1.15e-01, acc(train)=9.53e-01, error(valid)=1.37e+00, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 86: 28.4s to complete
#     error(train)=1.02e-01, acc(train)=9.57e-01, error(valid)=1.33e+00, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 87: 25.0s to complete
#     error(train)=1.02e-01, acc(train)=9.58e-01, error(valid)=1.36e+00, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 88: 25.1s to complete
#     error(train)=1.07e-01, acc(train)=9.57e-01, error(valid)=1.37e+00, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 89: 29.7s to complete
#     error(train)=1.09e-01, acc(train)=9.56e-01, error(valid)=1.43e+00, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 90: 25.6s to complete
#     error(train)=1.15e-01, acc(train)=9.55e-01, error(valid)=1.42e+00, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 91: 31.1s to complete
#     error(train)=1.11e-01, acc(train)=9.55e-01, error(valid)=1.44e+00, acc(valid)=8.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 92: 29.7s to complete
#     error(train)=1.11e-01, acc(train)=9.56e-01, error(valid)=1.45e+00, acc(valid)=8.17e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 93: 27.4s to complete
#     error(train)=9.55e-02, acc(train)=9.61e-01, error(valid)=1.45e+00, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 94: 25.6s to complete
#     error(train)=1.00e-01, acc(train)=9.58e-01, error(valid)=1.45e+00, acc(valid)=8.17e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 95: 28.8s to complete
#     error(train)=9.66e-02, acc(train)=9.60e-01, error(valid)=1.52e+00, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 96: 27.9s to complete
#     error(train)=1.05e-01, acc(train)=9.58e-01, error(valid)=1.49e+00, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 97: 41.5s to complete
#     error(train)=9.52e-02, acc(train)=9.61e-01, error(valid)=1.53e+00, acc(valid)=8.14e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 98: 33.9s to complete
#     error(train)=1.05e-01, acc(train)=9.57e-01, error(valid)=1.50e+00, acc(valid)=8.13e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 99: 28.7s to complete
#     error(train)=9.58e-02, acc(train)=9.61e-01, error(valid)=1.52e+00, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 100: 32.4s to complete
#     error(train)=9.39e-02, acc(train)=9.62e-01, error(valid)=1.54e+00, acc(valid)=8.21e-01
# OrderedDict([('error(test)', 1.7010295992674642), ('acc(test)', 0.8089240506329111)])

# %% [markdown]
# ### hidden units 32, hidden layers 3

# %%
#Base Line ReLu
# Reset random number generator and data provider states on each run
# to ensure reproducibility of results
rng.seed(seed)
train_data.reset()
valid_data.reset()
#setup hyperparameters
learning_rate = 0.01
num_epochs = 100
stats_interval = 1
input_dim, output_dim = 784, 47
hidden_dim = 32

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule()

#Remember to use notebook=False when you write a script to be run in a terminal
#return stats, keys, run_time, fig_1, ax_1, fig_2, ax_2
_= train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 1: 7.7s to complete
#     error(train)=1.18e+00, acc(train)=6.56e-01, error(valid)=1.19e+00, acc(valid)=6.55e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 2: 5.8s to complete
#     error(train)=9.86e-01, acc(train)=7.10e-01, error(valid)=1.00e+00, acc(valid)=7.10e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 3: 3.6s to complete
#     error(train)=8.84e-01, acc(train)=7.34e-01, error(valid)=9.07e-01, acc(valid)=7.31e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 4: 4.0s to complete
#     error(train)=8.57e-01, acc(train)=7.37e-01, error(valid)=8.95e-01, acc(valid)=7.29e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 5: 5.5s to complete
#     error(train)=7.95e-01, acc(train)=7.56e-01, error(valid)=8.42e-01, acc(valid)=7.45e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 6: 3.9s to complete
#     error(train)=7.55e-01, acc(train)=7.67e-01, error(valid)=8.03e-01, acc(valid)=7.57e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 7: 4.0s to complete
#     error(train)=7.13e-01, acc(train)=7.80e-01, error(valid)=7.71e-01, acc(valid)=7.66e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 8: 3.9s to complete
#     error(train)=6.99e-01, acc(train)=7.81e-01, error(valid)=7.55e-01, acc(valid)=7.67e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 9: 3.6s to complete
#     error(train)=6.69e-01, acc(train)=7.90e-01, error(valid)=7.29e-01, acc(valid)=7.73e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 10: 3.7s to complete
#     error(train)=6.58e-01, acc(train)=7.93e-01, error(valid)=7.22e-01, acc(valid)=7.78e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 11: 3.7s to complete
#     error(train)=6.50e-01, acc(train)=7.96e-01, error(valid)=7.16e-01, acc(valid)=7.79e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 12: 3.8s to complete
#     error(train)=6.43e-01, acc(train)=7.93e-01, error(valid)=7.12e-01, acc(valid)=7.75e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 13: 3.5s to complete
#     error(train)=6.36e-01, acc(train)=7.96e-01, error(valid)=7.03e-01, acc(valid)=7.79e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 14: 3.4s to complete
#     error(train)=6.25e-01, acc(train)=7.98e-01, error(valid)=7.01e-01, acc(valid)=7.81e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 15: 3.8s to complete
#     error(train)=6.05e-01, acc(train)=8.05e-01, error(valid)=6.88e-01, acc(valid)=7.82e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 16: 3.8s to complete
#     error(train)=5.94e-01, acc(train)=8.07e-01, error(valid)=6.75e-01, acc(valid)=7.84e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 17: 4.5s to complete
#     error(train)=6.00e-01, acc(train)=8.05e-01, error(valid)=6.89e-01, acc(valid)=7.83e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 18: 4.7s to complete
#     error(train)=5.84e-01, acc(train)=8.09e-01, error(valid)=6.72e-01, acc(valid)=7.89e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 19: 3.5s to complete
#     error(train)=5.76e-01, acc(train)=8.12e-01, error(valid)=6.63e-01, acc(valid)=7.90e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 20: 3.6s to complete
#     error(train)=5.69e-01, acc(train)=8.13e-01, error(valid)=6.60e-01, acc(valid)=7.90e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 21: 3.9s to complete
#     error(train)=5.57e-01, acc(train)=8.18e-01, error(valid)=6.53e-01, acc(valid)=7.95e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 22: 3.3s to complete
#     error(train)=5.56e-01, acc(train)=8.16e-01, error(valid)=6.54e-01, acc(valid)=7.93e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 23: 3.7s to complete
#     error(train)=5.47e-01, acc(train)=8.20e-01, error(valid)=6.51e-01, acc(valid)=7.96e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 24: 3.5s to complete
#     error(train)=5.46e-01, acc(train)=8.20e-01, error(valid)=6.54e-01, acc(valid)=7.93e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 25: 3.6s to complete
#     error(train)=5.49e-01, acc(train)=8.19e-01, error(valid)=6.56e-01, acc(valid)=7.93e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 26: 3.5s to complete
#     error(train)=5.44e-01, acc(train)=8.20e-01, error(valid)=6.52e-01, acc(valid)=7.94e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 27: 3.4s to complete
#     error(train)=5.41e-01, acc(train)=8.21e-01, error(valid)=6.55e-01, acc(valid)=7.95e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 28: 5.0s to complete
#     error(train)=5.36e-01, acc(train)=8.22e-01, error(valid)=6.50e-01, acc(valid)=7.92e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 29: 4.2s to complete
#     error(train)=5.25e-01, acc(train)=8.27e-01, error(valid)=6.41e-01, acc(valid)=8.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 30: 4.0s to complete
#     error(train)=5.36e-01, acc(train)=8.22e-01, error(valid)=6.54e-01, acc(valid)=7.97e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 31: 4.1s to complete
#     error(train)=5.37e-01, acc(train)=8.24e-01, error(valid)=6.56e-01, acc(valid)=7.96e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 32: 3.6s to complete
#     error(train)=5.22e-01, acc(train)=8.27e-01, error(valid)=6.43e-01, acc(valid)=8.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 33: 3.5s to complete
#     error(train)=5.23e-01, acc(train)=8.25e-01, error(valid)=6.44e-01, acc(valid)=7.99e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 34: 4.3s to complete
#     error(train)=5.14e-01, acc(train)=8.28e-01, error(valid)=6.41e-01, acc(valid)=8.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 35: 4.2s to complete
#     error(train)=5.16e-01, acc(train)=8.28e-01, error(valid)=6.45e-01, acc(valid)=7.96e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 36: 3.8s to complete
#     error(train)=5.20e-01, acc(train)=8.29e-01, error(valid)=6.50e-01, acc(valid)=7.96e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 37: 3.8s to complete
#     error(train)=5.09e-01, acc(train)=8.29e-01, error(valid)=6.39e-01, acc(valid)=8.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 38: 4.0s to complete
#     error(train)=5.03e-01, acc(train)=8.32e-01, error(valid)=6.37e-01, acc(valid)=8.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 39: 3.7s to complete
#     error(train)=5.06e-01, acc(train)=8.31e-01, error(valid)=6.40e-01, acc(valid)=7.99e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 40: 4.2s to complete
#     error(train)=5.13e-01, acc(train)=8.29e-01, error(valid)=6.46e-01, acc(valid)=8.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 41: 4.3s to complete
#     error(train)=5.09e-01, acc(train)=8.29e-01, error(valid)=6.44e-01, acc(valid)=8.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 42: 4.3s to complete
#     error(train)=5.04e-01, acc(train)=8.31e-01, error(valid)=6.48e-01, acc(valid)=7.98e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 43: 4.0s to complete
#     error(train)=5.06e-01, acc(train)=8.29e-01, error(valid)=6.49e-01, acc(valid)=7.96e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 44: 3.7s to complete
#     error(train)=5.09e-01, acc(train)=8.28e-01, error(valid)=6.52e-01, acc(valid)=7.95e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 45: 3.9s to complete
#     error(train)=5.18e-01, acc(train)=8.23e-01, error(valid)=6.67e-01, acc(valid)=7.92e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 46: 3.7s to complete
#     error(train)=4.87e-01, acc(train)=8.36e-01, error(valid)=6.32e-01, acc(valid)=8.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 47: 4.7s to complete
#     error(train)=4.97e-01, acc(train)=8.34e-01, error(valid)=6.41e-01, acc(valid)=8.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 48: 4.1s to complete
#     error(train)=4.97e-01, acc(train)=8.34e-01, error(valid)=6.44e-01, acc(valid)=8.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 49: 3.3s to complete
#     error(train)=5.01e-01, acc(train)=8.30e-01, error(valid)=6.53e-01, acc(valid)=7.93e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 50: 3.6s to complete
#     error(train)=4.92e-01, acc(train)=8.34e-01, error(valid)=6.46e-01, acc(valid)=7.98e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 51: 4.0s to complete
#     error(train)=4.86e-01, acc(train)=8.36e-01, error(valid)=6.37e-01, acc(valid)=8.03e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 52: 3.5s to complete
#     error(train)=4.89e-01, acc(train)=8.37e-01, error(valid)=6.48e-01, acc(valid)=8.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 53: 3.5s to complete
#     error(train)=4.80e-01, acc(train)=8.39e-01, error(valid)=6.35e-01, acc(valid)=8.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 54: 3.3s to complete
#     error(train)=4.82e-01, acc(train)=8.37e-01, error(valid)=6.37e-01, acc(valid)=8.03e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 55: 3.8s to complete
#     error(train)=4.86e-01, acc(train)=8.36e-01, error(valid)=6.44e-01, acc(valid)=8.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 56: 3.5s to complete
#     error(train)=4.86e-01, acc(train)=8.38e-01, error(valid)=6.45e-01, acc(valid)=8.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 57: 4.2s to complete
#     error(train)=4.80e-01, acc(train)=8.37e-01, error(valid)=6.43e-01, acc(valid)=7.98e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 58: 3.3s to complete
#     error(train)=4.76e-01, acc(train)=8.38e-01, error(valid)=6.38e-01, acc(valid)=8.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 59: 4.2s to complete
#     error(train)=4.77e-01, acc(train)=8.37e-01, error(valid)=6.44e-01, acc(valid)=7.99e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 60: 3.8s to complete
#     error(train)=4.78e-01, acc(train)=8.37e-01, error(valid)=6.47e-01, acc(valid)=8.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 61: 5.0s to complete
#     error(train)=4.77e-01, acc(train)=8.37e-01, error(valid)=6.45e-01, acc(valid)=8.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 62: 3.5s to complete
#     error(train)=4.85e-01, acc(train)=8.35e-01, error(valid)=6.57e-01, acc(valid)=7.96e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 63: 4.0s to complete
#     error(train)=4.65e-01, acc(train)=8.44e-01, error(valid)=6.30e-01, acc(valid)=8.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 64: 4.6s to complete
#     error(train)=4.66e-01, acc(train)=8.42e-01, error(valid)=6.35e-01, acc(valid)=8.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 65: 5.2s to complete
#     error(train)=4.66e-01, acc(train)=8.41e-01, error(valid)=6.39e-01, acc(valid)=8.03e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 66: 3.9s to complete
#     error(train)=4.70e-01, acc(train)=8.41e-01, error(valid)=6.37e-01, acc(valid)=8.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 67: 3.7s to complete
#     error(train)=4.97e-01, acc(train)=8.32e-01, error(valid)=6.67e-01, acc(valid)=7.99e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 68: 4.5s to complete
#     error(train)=4.74e-01, acc(train)=8.38e-01, error(valid)=6.47e-01, acc(valid)=8.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 69: 3.2s to complete
#     error(train)=4.68e-01, acc(train)=8.42e-01, error(valid)=6.45e-01, acc(valid)=8.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 70: 3.7s to complete
#     error(train)=4.85e-01, acc(train)=8.32e-01, error(valid)=6.66e-01, acc(valid)=7.93e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 71: 4.5s to complete
#     error(train)=4.74e-01, acc(train)=8.38e-01, error(valid)=6.54e-01, acc(valid)=8.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 72: 4.9s to complete
#     error(train)=4.59e-01, acc(train)=8.40e-01, error(valid)=6.41e-01, acc(valid)=7.99e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 73: 3.4s to complete
#     error(train)=4.53e-01, acc(train)=8.47e-01, error(valid)=6.34e-01, acc(valid)=8.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 74: 3.6s to complete
#     error(train)=4.67e-01, acc(train)=8.39e-01, error(valid)=6.51e-01, acc(valid)=7.99e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 75: 4.7s to complete
#     error(train)=4.65e-01, acc(train)=8.41e-01, error(valid)=6.46e-01, acc(valid)=8.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 76: 8.0s to complete
#     error(train)=4.53e-01, acc(train)=8.46e-01, error(valid)=6.37e-01, acc(valid)=8.04e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 77: 3.1s to complete
#     error(train)=4.55e-01, acc(train)=8.44e-01, error(valid)=6.43e-01, acc(valid)=8.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 78: 6.4s to complete
#     error(train)=4.60e-01, acc(train)=8.43e-01, error(valid)=6.52e-01, acc(valid)=8.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 79: 4.4s to complete
#     error(train)=4.58e-01, acc(train)=8.44e-01, error(valid)=6.45e-01, acc(valid)=8.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 80: 3.3s to complete
#     error(train)=4.59e-01, acc(train)=8.43e-01, error(valid)=6.46e-01, acc(valid)=8.03e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 81: 3.5s to complete
#     error(train)=4.65e-01, acc(train)=8.42e-01, error(valid)=6.53e-01, acc(valid)=8.03e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 82: 4.3s to complete
#     error(train)=4.73e-01, acc(train)=8.39e-01, error(valid)=6.65e-01, acc(valid)=7.98e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 83: 2.9s to complete
#     error(train)=4.54e-01, acc(train)=8.46e-01, error(valid)=6.49e-01, acc(valid)=8.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 84: 3.0s to complete
#     error(train)=4.51e-01, acc(train)=8.46e-01, error(valid)=6.43e-01, acc(valid)=8.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 85: 4.7s to complete
#     error(train)=4.58e-01, acc(train)=8.42e-01, error(valid)=6.50e-01, acc(valid)=8.01e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 86: 4.2s to complete
#     error(train)=4.60e-01, acc(train)=8.42e-01, error(valid)=6.50e-01, acc(valid)=7.99e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 87: 3.0s to complete
#     error(train)=4.51e-01, acc(train)=8.47e-01, error(valid)=6.45e-01, acc(valid)=8.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 88: 2.9s to complete
#     error(train)=4.51e-01, acc(train)=8.46e-01, error(valid)=6.50e-01, acc(valid)=8.03e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 89: 4.0s to complete
#     error(train)=4.58e-01, acc(train)=8.43e-01, error(valid)=6.50e-01, acc(valid)=8.03e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 90: 3.0s to complete
#     error(train)=4.45e-01, acc(train)=8.48e-01, error(valid)=6.44e-01, acc(valid)=8.03e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 91: 2.7s to complete
#     error(train)=4.48e-01, acc(train)=8.46e-01, error(valid)=6.49e-01, acc(valid)=8.03e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 92: 3.7s to complete
#     error(train)=4.60e-01, acc(train)=8.42e-01, error(valid)=6.59e-01, acc(valid)=7.97e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 93: 3.9s to complete
#     error(train)=4.45e-01, acc(train)=8.48e-01, error(valid)=6.46e-01, acc(valid)=8.04e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 94: 3.8s to complete
#     error(train)=4.47e-01, acc(train)=8.47e-01, error(valid)=6.52e-01, acc(valid)=8.03e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 95: 3.8s to complete
#     error(train)=4.68e-01, acc(train)=8.38e-01, error(valid)=6.72e-01, acc(valid)=7.96e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 96: 3.8s to complete
#     error(train)=4.45e-01, acc(train)=8.48e-01, error(valid)=6.51e-01, acc(valid)=8.04e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 97: 3.8s to complete
#     error(train)=4.45e-01, acc(train)=8.48e-01, error(valid)=6.55e-01, acc(valid)=8.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 98: 3.9s to complete
#     error(train)=4.59e-01, acc(train)=8.45e-01, error(valid)=6.65e-01, acc(valid)=8.00e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 99: 3.8s to complete
#     error(train)=4.47e-01, acc(train)=8.46e-01, error(valid)=6.53e-01, acc(valid)=8.02e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 100: 3.7s to complete
#     error(train)=4.57e-01, acc(train)=8.41e-01, error(valid)=6.63e-01, acc(valid)=7.98e-01
# OrderedDict([('error(test)', 0.6917883073726496), ('acc(test)', 0.7864556962025316)])

# %% [markdown]
# ### hidden units 64, hidden layers 3

# %%
#Base Line ReLu
# Reset random number generator and data provider states on each run
# to ensure reproducibility of results
rng.seed(seed)
train_data.reset()
valid_data.reset()
#setup hyperparameters
learning_rate = 0.01
num_epochs = 100
stats_interval = 1
input_dim, output_dim = 784, 47
hidden_dim = 64

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule()

#Remember to use notebook=False when you write a script to be run in a terminal
#return stats, keys, run_time, fig_1, ax_1, fig_2, ax_2
_= train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 1: 5.6s to complete
#     error(train)=8.85e-01, acc(train)=7.34e-01, error(valid)=9.08e-01, acc(valid)=7.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 2: 4.8s to complete
#     error(train)=7.23e-01, acc(train)=7.73e-01, error(valid)=7.61e-01, acc(valid)=7.61e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 3: 4.7s to complete
#     error(train)=6.33e-01, acc(train)=7.97e-01, error(valid)=6.76e-01, acc(valid)=7.81e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 4: 6.1s to complete
#     error(train)=5.88e-01, acc(train)=8.11e-01, error(valid)=6.37e-01, acc(valid)=7.97e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 5: 5.3s to complete
#     error(train)=5.48e-01, acc(train)=8.22e-01, error(valid)=6.07e-01, acc(valid)=8.05e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 6: 5.8s to complete
#     error(train)=5.26e-01, acc(train)=8.25e-01, error(valid)=6.00e-01, acc(valid)=8.04e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 7: 4.6s to complete
#     error(train)=4.95e-01, acc(train)=8.35e-01, error(valid)=5.74e-01, acc(valid)=8.15e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 8: 5.1s to complete
#     error(train)=4.76e-01, acc(train)=8.40e-01, error(valid)=5.68e-01, acc(valid)=8.15e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 9: 4.9s to complete
#     error(train)=4.71e-01, acc(train)=8.42e-01, error(valid)=5.67e-01, acc(valid)=8.17e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 10: 5.6s to complete
#     error(train)=4.49e-01, acc(train)=8.45e-01, error(valid)=5.53e-01, acc(valid)=8.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 11: 4.7s to complete
#     error(train)=4.41e-01, acc(train)=8.48e-01, error(valid)=5.53e-01, acc(valid)=8.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 12: 4.7s to complete
#     error(train)=4.38e-01, acc(train)=8.47e-01, error(valid)=5.57e-01, acc(valid)=8.15e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 13: 4.6s to complete
#     error(train)=4.22e-01, acc(train)=8.55e-01, error(valid)=5.52e-01, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 14: 7.0s to complete
#     error(train)=4.16e-01, acc(train)=8.51e-01, error(valid)=5.46e-01, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 15: 10.1s to complete
#     error(train)=4.09e-01, acc(train)=8.56e-01, error(valid)=5.46e-01, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 16: 5.9s to complete
#     error(train)=4.00e-01, acc(train)=8.59e-01, error(valid)=5.48e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 17: 4.9s to complete
#     error(train)=3.85e-01, acc(train)=8.66e-01, error(valid)=5.44e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 18: 4.4s to complete
#     error(train)=3.88e-01, acc(train)=8.63e-01, error(valid)=5.55e-01, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 19: 4.6s to complete
#     error(train)=3.81e-01, acc(train)=8.64e-01, error(valid)=5.51e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 20: 5.8s to complete
#     error(train)=3.75e-01, acc(train)=8.65e-01, error(valid)=5.52e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 21: 5.1s to complete
#     error(train)=3.65e-01, acc(train)=8.71e-01, error(valid)=5.42e-01, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 22: 5.0s to complete
#     error(train)=3.53e-01, acc(train)=8.74e-01, error(valid)=5.48e-01, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 23: 4.6s to complete
#     error(train)=3.56e-01, acc(train)=8.72e-01, error(valid)=5.60e-01, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 24: 4.8s to complete
#     error(train)=3.54e-01, acc(train)=8.72e-01, error(valid)=5.62e-01, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 25: 4.6s to complete
#     error(train)=3.50e-01, acc(train)=8.73e-01, error(valid)=5.59e-01, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 26: 4.5s to complete
#     error(train)=3.49e-01, acc(train)=8.73e-01, error(valid)=5.73e-01, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 27: 5.1s to complete
#     error(train)=3.39e-01, acc(train)=8.77e-01, error(valid)=5.60e-01, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 28: 4.6s to complete
#     error(train)=3.33e-01, acc(train)=8.78e-01, error(valid)=5.70e-01, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 29: 4.9s to complete
#     error(train)=3.19e-01, acc(train)=8.83e-01, error(valid)=5.51e-01, acc(valid)=8.29e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 30: 4.5s to complete
#     error(train)=3.23e-01, acc(train)=8.82e-01, error(valid)=5.66e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 31: 4.9s to complete
#     error(train)=3.22e-01, acc(train)=8.83e-01, error(valid)=5.60e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 32: 4.6s to complete
#     error(train)=3.34e-01, acc(train)=8.77e-01, error(valid)=5.86e-01, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 33: 5.2s to complete
#     error(train)=3.27e-01, acc(train)=8.79e-01, error(valid)=5.90e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 34: 4.6s to complete
#     error(train)=3.28e-01, acc(train)=8.79e-01, error(valid)=5.95e-01, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 35: 4.7s to complete
#     error(train)=3.16e-01, acc(train)=8.82e-01, error(valid)=5.90e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 36: 5.0s to complete
#     error(train)=3.10e-01, acc(train)=8.85e-01, error(valid)=5.87e-01, acc(valid)=8.27e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 37: 4.6s to complete
#     error(train)=3.13e-01, acc(train)=8.82e-01, error(valid)=6.01e-01, acc(valid)=8.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 38: 4.8s to complete
#     error(train)=3.04e-01, acc(train)=8.87e-01, error(valid)=5.98e-01, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 39: 4.6s to complete
#     error(train)=3.16e-01, acc(train)=8.82e-01, error(valid)=6.31e-01, acc(valid)=8.17e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 40: 5.0s to complete
#     error(train)=3.06e-01, acc(train)=8.85e-01, error(valid)=6.09e-01, acc(valid)=8.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 41: 4.5s to complete
#     error(train)=3.04e-01, acc(train)=8.87e-01, error(valid)=6.18e-01, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 42: 6.9s to complete
#     error(train)=3.01e-01, acc(train)=8.87e-01, error(valid)=6.15e-01, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 43: 4.5s to complete
#     error(train)=2.89e-01, acc(train)=8.91e-01, error(valid)=6.07e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 44: 4.5s to complete
#     error(train)=2.95e-01, acc(train)=8.88e-01, error(valid)=6.17e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 45: 4.6s to complete
#     error(train)=2.94e-01, acc(train)=8.88e-01, error(valid)=6.21e-01, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 46: 4.8s to complete
#     error(train)=3.02e-01, acc(train)=8.85e-01, error(valid)=6.31e-01, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 47: 4.7s to complete
#     error(train)=2.88e-01, acc(train)=8.91e-01, error(valid)=6.42e-01, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 48: 4.6s to complete
#     error(train)=2.87e-01, acc(train)=8.91e-01, error(valid)=6.39e-01, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 49: 4.6s to complete
#     error(train)=2.86e-01, acc(train)=8.91e-01, error(valid)=6.45e-01, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 50: 4.7s to complete
#     error(train)=2.75e-01, acc(train)=8.96e-01, error(valid)=6.37e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 51: 4.8s to complete
#     error(train)=2.83e-01, acc(train)=8.94e-01, error(valid)=6.51e-01, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 52: 4.8s to complete
#     error(train)=2.87e-01, acc(train)=8.91e-01, error(valid)=6.60e-01, acc(valid)=8.15e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 53: 4.7s to complete
#     error(train)=2.77e-01, acc(train)=8.95e-01, error(valid)=6.57e-01, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 54: 4.6s to complete
#     error(train)=2.73e-01, acc(train)=8.97e-01, error(valid)=6.49e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 55: 4.6s to complete
#     error(train)=2.72e-01, acc(train)=8.96e-01, error(valid)=6.58e-01, acc(valid)=8.17e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 56: 4.8s to complete
#     error(train)=2.75e-01, acc(train)=8.95e-01, error(valid)=6.77e-01, acc(valid)=8.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 57: 4.7s to complete
#     error(train)=2.65e-01, acc(train)=8.99e-01, error(valid)=6.63e-01, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 58: 4.6s to complete
#     error(train)=2.82e-01, acc(train)=8.92e-01, error(valid)=6.91e-01, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 59: 4.7s to complete
#     error(train)=2.70e-01, acc(train)=8.97e-01, error(valid)=6.84e-01, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 60: 4.6s to complete
#     error(train)=2.71e-01, acc(train)=8.97e-01, error(valid)=6.90e-01, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 61: 4.7s to complete
#     error(train)=2.75e-01, acc(train)=8.95e-01, error(valid)=6.92e-01, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 62: 4.7s to complete
#     error(train)=2.49e-01, acc(train)=9.04e-01, error(valid)=7.00e-01, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 63: 4.9s to complete
#     error(train)=2.62e-01, acc(train)=8.99e-01, error(valid)=7.18e-01, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 64: 4.9s to complete
#     error(train)=2.51e-01, acc(train)=9.03e-01, error(valid)=6.84e-01, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 65: 5.0s to complete
#     error(train)=2.68e-01, acc(train)=8.97e-01, error(valid)=7.26e-01, acc(valid)=8.15e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 66: 4.9s to complete
#     error(train)=2.58e-01, acc(train)=9.01e-01, error(valid)=7.09e-01, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 67: 4.8s to complete
#     error(train)=2.67e-01, acc(train)=8.97e-01, error(valid)=7.19e-01, acc(valid)=8.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 68: 5.0s to complete
#     error(train)=2.48e-01, acc(train)=9.04e-01, error(valid)=7.10e-01, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 69: 4.7s to complete
#     error(train)=2.56e-01, acc(train)=9.02e-01, error(valid)=7.28e-01, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 70: 4.8s to complete
#     error(train)=2.52e-01, acc(train)=9.02e-01, error(valid)=7.16e-01, acc(valid)=8.15e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 71: 4.8s to complete
#     error(train)=2.56e-01, acc(train)=9.00e-01, error(valid)=7.17e-01, acc(valid)=8.17e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 72: 4.7s to complete
#     error(train)=2.60e-01, acc(train)=9.00e-01, error(valid)=7.31e-01, acc(valid)=8.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 73: 4.7s to complete
#     error(train)=2.41e-01, acc(train)=9.07e-01, error(valid)=7.28e-01, acc(valid)=8.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 74: 4.8s to complete
#     error(train)=2.44e-01, acc(train)=9.06e-01, error(valid)=7.41e-01, acc(valid)=8.14e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 75: 5.4s to complete
#     error(train)=2.37e-01, acc(train)=9.07e-01, error(valid)=7.41e-01, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 76: 5.1s to complete
#     error(train)=2.49e-01, acc(train)=9.04e-01, error(valid)=7.53e-01, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 77: 5.1s to complete
#     error(train)=2.54e-01, acc(train)=9.02e-01, error(valid)=7.39e-01, acc(valid)=8.14e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 78: 4.8s to complete
#     error(train)=2.41e-01, acc(train)=9.07e-01, error(valid)=7.70e-01, acc(valid)=8.15e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 79: 4.8s to complete
#     error(train)=2.50e-01, acc(train)=9.03e-01, error(valid)=7.72e-01, acc(valid)=8.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 80: 4.9s to complete
#     error(train)=2.42e-01, acc(train)=9.06e-01, error(valid)=7.62e-01, acc(valid)=8.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 81: 5.0s to complete
#     error(train)=2.56e-01, acc(train)=9.01e-01, error(valid)=7.91e-01, acc(valid)=8.09e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 82: 4.9s to complete
#     error(train)=2.36e-01, acc(train)=9.08e-01, error(valid)=7.72e-01, acc(valid)=8.14e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 83: 5.2s to complete
#     error(train)=2.31e-01, acc(train)=9.11e-01, error(valid)=7.83e-01, acc(valid)=8.17e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 84: 4.8s to complete
#     error(train)=2.31e-01, acc(train)=9.11e-01, error(valid)=7.88e-01, acc(valid)=8.18e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 85: 4.8s to complete
#     error(train)=2.39e-01, acc(train)=9.06e-01, error(valid)=7.95e-01, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 86: 5.3s to complete
#     error(train)=2.30e-01, acc(train)=9.10e-01, error(valid)=7.84e-01, acc(valid)=8.17e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 87: 6.0s to complete
#     error(train)=2.37e-01, acc(train)=9.08e-01, error(valid)=7.83e-01, acc(valid)=8.17e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 88: 4.8s to complete
#     error(train)=2.37e-01, acc(train)=9.06e-01, error(valid)=7.94e-01, acc(valid)=8.10e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 89: 4.8s to complete
#     error(train)=2.38e-01, acc(train)=9.05e-01, error(valid)=7.97e-01, acc(valid)=8.11e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 90: 4.9s to complete
#     error(train)=2.34e-01, acc(train)=9.09e-01, error(valid)=8.12e-01, acc(valid)=8.12e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 91: 4.8s to complete
#     error(train)=2.37e-01, acc(train)=9.06e-01, error(valid)=8.10e-01, acc(valid)=8.13e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 92: 4.9s to complete
#     error(train)=2.20e-01, acc(train)=9.14e-01, error(valid)=8.03e-01, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 93: 4.8s to complete
#     error(train)=2.33e-01, acc(train)=9.09e-01, error(valid)=8.18e-01, acc(valid)=8.14e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 94: 4.8s to complete
#     error(train)=2.45e-01, acc(train)=9.04e-01, error(valid)=8.29e-01, acc(valid)=8.09e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 95: 5.0s to complete
#     error(train)=2.19e-01, acc(train)=9.14e-01, error(valid)=8.30e-01, acc(valid)=8.16e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 96: 5.2s to complete
#     error(train)=2.40e-01, acc(train)=9.06e-01, error(valid)=8.45e-01, acc(valid)=8.06e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 97: 5.0s to complete
#     error(train)=2.33e-01, acc(train)=9.07e-01, error(valid)=8.38e-01, acc(valid)=8.11e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 98: 5.6s to complete
#     error(train)=2.35e-01, acc(train)=9.07e-01, error(valid)=8.43e-01, acc(valid)=8.09e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 99: 4.9s to complete
#     error(train)=2.17e-01, acc(train)=9.14e-01, error(valid)=8.45e-01, acc(valid)=8.13e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 100: 4.8s to complete
#     error(train)=2.22e-01, acc(train)=9.11e-01, error(valid)=8.53e-01, acc(valid)=8.09e-01
# OrderedDict([('error(test)', 0.9324850215323651), ('acc(test)', 0.7958227848101264)])

# %% [markdown]
# ### hidden units 128, hidden layers 3

# %%
#Base Line ReLu
# Reset random number generator and data provider states on each run
# to ensure reproducibility of results
rng.seed(seed)
train_data.reset()
valid_data.reset()
#setup hyperparameters
learning_rate = 0.01
num_epochs = 100
stats_interval = 1
input_dim, output_dim = 784, 47
hidden_dim = 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = AdamLearningRule()

#Remember to use notebook=False when you write a script to be run in a terminal
#return stats, keys, run_time, fig_1, ax_1, fig_2, ax_2
_= train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 1: 10.3s to complete
#     error(train)=7.16e-01, acc(train)=7.71e-01, error(valid)=7.35e-01, acc(valid)=7.69e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 2: 14.6s to complete
#     error(train)=5.64e-01, acc(train)=8.16e-01, error(valid)=6.08e-01, acc(valid)=8.04e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 3: 9.7s to complete
#     error(train)=4.69e-01, acc(train)=8.40e-01, error(valid)=5.35e-01, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 4: 9.9s to complete
#     error(train)=4.31e-01, acc(train)=8.46e-01, error(valid)=5.14e-01, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 5: 11.8s to complete
#     error(train)=4.11e-01, acc(train)=8.56e-01, error(valid)=5.11e-01, acc(valid)=8.29e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 6: 10.7s to complete
#     error(train)=3.87e-01, acc(train)=8.62e-01, error(valid)=5.08e-01, acc(valid)=8.29e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 7: 9.5s to complete
#     error(train)=3.64e-01, acc(train)=8.68e-01, error(valid)=5.05e-01, acc(valid)=8.32e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 8: 12.5s to complete
#     error(train)=3.36e-01, acc(train)=8.78e-01, error(valid)=4.88e-01, acc(valid)=8.39e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 9: 10.1s to complete
#     error(train)=3.24e-01, acc(train)=8.80e-01, error(valid)=4.94e-01, acc(valid)=8.40e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 10: 9.7s to complete
#     error(train)=3.19e-01, acc(train)=8.81e-01, error(valid)=5.07e-01, acc(valid)=8.38e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 11: 11.6s to complete
#     error(train)=3.03e-01, acc(train)=8.85e-01, error(valid)=5.05e-01, acc(valid)=8.37e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 12: 12.8s to complete
#     error(train)=2.93e-01, acc(train)=8.89e-01, error(valid)=5.13e-01, acc(valid)=8.39e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 13: 14.2s to complete
#     error(train)=2.75e-01, acc(train)=8.96e-01, error(valid)=5.09e-01, acc(valid)=8.40e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 14: 16.1s to complete
#     error(train)=2.68e-01, acc(train)=8.98e-01, error(valid)=5.13e-01, acc(valid)=8.40e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 15: 11.4s to complete
#     error(train)=2.52e-01, acc(train)=9.02e-01, error(valid)=5.18e-01, acc(valid)=8.42e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 16: 10.4s to complete
#     error(train)=2.48e-01, acc(train)=9.03e-01, error(valid)=5.41e-01, acc(valid)=8.40e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 17: 10.5s to complete
#     error(train)=2.41e-01, acc(train)=9.05e-01, error(valid)=5.52e-01, acc(valid)=8.38e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 18: 10.0s to complete
#     error(train)=2.29e-01, acc(train)=9.10e-01, error(valid)=5.48e-01, acc(valid)=8.38e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 19: 12.1s to complete
#     error(train)=2.30e-01, acc(train)=9.09e-01, error(valid)=5.72e-01, acc(valid)=8.37e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 20: 10.1s to complete
#     error(train)=2.26e-01, acc(train)=9.09e-01, error(valid)=5.76e-01, acc(valid)=8.40e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 21: 10.0s to complete
#     error(train)=2.19e-01, acc(train)=9.13e-01, error(valid)=5.90e-01, acc(valid)=8.36e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 22: 10.1s to complete
#     error(train)=2.29e-01, acc(train)=9.07e-01, error(valid)=6.21e-01, acc(valid)=8.32e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 23: 10.1s to complete
#     error(train)=2.24e-01, acc(train)=9.10e-01, error(valid)=6.36e-01, acc(valid)=8.32e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 24: 10.0s to complete
#     error(train)=2.09e-01, acc(train)=9.15e-01, error(valid)=6.47e-01, acc(valid)=8.34e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 25: 10.6s to complete
#     error(train)=2.01e-01, acc(train)=9.18e-01, error(valid)=6.46e-01, acc(valid)=8.33e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 26: 10.4s to complete
#     error(train)=1.90e-01, acc(train)=9.22e-01, error(valid)=6.58e-01, acc(valid)=8.33e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 27: 10.5s to complete
#     error(train)=2.02e-01, acc(train)=9.18e-01, error(valid)=6.95e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 28: 10.4s to complete
#     error(train)=1.85e-01, acc(train)=9.25e-01, error(valid)=6.64e-01, acc(valid)=8.33e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 29: 10.2s to complete
#     error(train)=1.87e-01, acc(train)=9.24e-01, error(valid)=6.98e-01, acc(valid)=8.33e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 30: 10.4s to complete
#     error(train)=1.85e-01, acc(train)=9.24e-01, error(valid)=7.16e-01, acc(valid)=8.30e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 31: 10.2s to complete
#     error(train)=1.85e-01, acc(train)=9.25e-01, error(valid)=7.61e-01, acc(valid)=8.30e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 32: 10.8s to complete
#     error(train)=1.75e-01, acc(train)=9.28e-01, error(valid)=7.20e-01, acc(valid)=8.33e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 33: 10.3s to complete
#     error(train)=1.72e-01, acc(train)=9.30e-01, error(valid)=7.58e-01, acc(valid)=8.34e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 34: 10.1s to complete
#     error(train)=1.66e-01, acc(train)=9.32e-01, error(valid)=7.47e-01, acc(valid)=8.34e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 35: 10.6s to complete
#     error(train)=1.66e-01, acc(train)=9.31e-01, error(valid)=7.76e-01, acc(valid)=8.35e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 36: 10.8s to complete
#     error(train)=1.66e-01, acc(train)=9.32e-01, error(valid)=8.23e-01, acc(valid)=8.29e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 37: 10.4s to complete
#     error(train)=1.72e-01, acc(train)=9.30e-01, error(valid)=8.17e-01, acc(valid)=8.32e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 38: 10.3s to complete
#     error(train)=1.55e-01, acc(train)=9.36e-01, error(valid)=8.19e-01, acc(valid)=8.32e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 39: 10.2s to complete
#     error(train)=1.55e-01, acc(train)=9.36e-01, error(valid)=8.38e-01, acc(valid)=8.31e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 40: 10.7s to complete
#     error(train)=1.67e-01, acc(train)=9.31e-01, error(valid)=8.56e-01, acc(valid)=8.31e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 41: 9.6s to complete
#     error(train)=1.56e-01, acc(train)=9.36e-01, error(valid)=8.78e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 42: 11.0s to complete
#     error(train)=1.44e-01, acc(train)=9.40e-01, error(valid)=8.81e-01, acc(valid)=8.32e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 43: 10.4s to complete
#     error(train)=1.51e-01, acc(train)=9.38e-01, error(valid)=9.01e-01, acc(valid)=8.27e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 44: 10.3s to complete
#     error(train)=1.56e-01, acc(train)=9.37e-01, error(valid)=9.17e-01, acc(valid)=8.32e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 45: 10.4s to complete
#     error(train)=1.48e-01, acc(train)=9.39e-01, error(valid)=9.38e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 46: 10.4s to complete
#     error(train)=1.58e-01, acc(train)=9.35e-01, error(valid)=9.91e-01, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 47: 10.5s to complete
#     error(train)=1.38e-01, acc(train)=9.42e-01, error(valid)=9.54e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 48: 9.8s to complete
#     error(train)=1.52e-01, acc(train)=9.38e-01, error(valid)=9.85e-01, acc(valid)=8.30e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 49: 12.2s to complete
#     error(train)=1.40e-01, acc(train)=9.42e-01, error(valid)=9.70e-01, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 50: 13.1s to complete
#     error(train)=1.54e-01, acc(train)=9.37e-01, error(valid)=1.03e+00, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 51: 10.8s to complete
#     error(train)=1.35e-01, acc(train)=9.43e-01, error(valid)=9.88e-01, acc(valid)=8.30e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 52: 10.7s to complete
#     error(train)=1.53e-01, acc(train)=9.38e-01, error(valid)=1.06e+00, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 53: 13.0s to complete
#     error(train)=1.41e-01, acc(train)=9.43e-01, error(valid)=1.05e+00, acc(valid)=8.32e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 54: 13.4s to complete
#     error(train)=1.36e-01, acc(train)=9.45e-01, error(valid)=1.06e+00, acc(valid)=8.28e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 55: 12.8s to complete
#     error(train)=1.34e-01, acc(train)=9.45e-01, error(valid)=1.05e+00, acc(valid)=8.31e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 56: 10.5s to complete
#     error(train)=1.38e-01, acc(train)=9.43e-01, error(valid)=1.10e+00, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 57: 10.7s to complete
#     error(train)=1.37e-01, acc(train)=9.44e-01, error(valid)=1.11e+00, acc(valid)=8.27e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 58: 10.6s to complete
#     error(train)=1.34e-01, acc(train)=9.46e-01, error(valid)=1.11e+00, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 59: 10.5s to complete
#     error(train)=1.38e-01, acc(train)=9.44e-01, error(valid)=1.12e+00, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 60: 11.0s to complete
#     error(train)=1.22e-01, acc(train)=9.50e-01, error(valid)=1.13e+00, acc(valid)=8.30e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 61: 10.4s to complete
#     error(train)=1.47e-01, acc(train)=9.41e-01, error(valid)=1.16e+00, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 62: 9.8s to complete
#     error(train)=1.31e-01, acc(train)=9.47e-01, error(valid)=1.18e+00, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 63: 10.6s to complete
#     error(train)=1.36e-01, acc(train)=9.46e-01, error(valid)=1.20e+00, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 64: 10.5s to complete
#     error(train)=1.20e-01, acc(train)=9.51e-01, error(valid)=1.19e+00, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 65: 10.8s to complete
#     error(train)=1.37e-01, acc(train)=9.45e-01, error(valid)=1.24e+00, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 66: 13.4s to complete
#     error(train)=1.25e-01, acc(train)=9.48e-01, error(valid)=1.25e+00, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 67: 11.9s to complete
#     error(train)=1.41e-01, acc(train)=9.45e-01, error(valid)=1.29e+00, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 68: 11.2s to complete
#     error(train)=1.32e-01, acc(train)=9.47e-01, error(valid)=1.25e+00, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 69: 12.4s to complete
#     error(train)=1.18e-01, acc(train)=9.52e-01, error(valid)=1.26e+00, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 70: 14.1s to complete
#     error(train)=1.32e-01, acc(train)=9.48e-01, error(valid)=1.29e+00, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 71: 15.3s to complete
#     error(train)=1.12e-01, acc(train)=9.55e-01, error(valid)=1.25e+00, acc(valid)=8.30e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 72: 14.8s to complete
#     error(train)=1.18e-01, acc(train)=9.52e-01, error(valid)=1.31e+00, acc(valid)=8.27e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 73: 13.2s to complete
#     error(train)=1.28e-01, acc(train)=9.50e-01, error(valid)=1.29e+00, acc(valid)=8.27e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 74: 11.1s to complete
#     error(train)=1.14e-01, acc(train)=9.53e-01, error(valid)=1.31e+00, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 75: 20.4s to complete
#     error(train)=1.15e-01, acc(train)=9.54e-01, error(valid)=1.33e+00, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 76: 8.8s to complete
#     error(train)=1.15e-01, acc(train)=9.54e-01, error(valid)=1.33e+00, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 77: 9.4s to complete
#     error(train)=1.15e-01, acc(train)=9.54e-01, error(valid)=1.35e+00, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 78: 10.6s to complete
#     error(train)=1.12e-01, acc(train)=9.56e-01, error(valid)=1.33e+00, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 79: 9.2s to complete
#     error(train)=1.32e-01, acc(train)=9.49e-01, error(valid)=1.43e+00, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 80: 8.5s to complete
#     error(train)=1.24e-01, acc(train)=9.52e-01, error(valid)=1.40e+00, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 81: 9.2s to complete
#     error(train)=1.18e-01, acc(train)=9.53e-01, error(valid)=1.43e+00, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 82: 9.1s to complete
#     error(train)=1.37e-01, acc(train)=9.50e-01, error(valid)=1.49e+00, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 83: 8.5s to complete
#     error(train)=1.23e-01, acc(train)=9.53e-01, error(valid)=1.43e+00, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 84: 7.2s to complete
#     error(train)=1.43e-01, acc(train)=9.47e-01, error(valid)=1.52e+00, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 85: 7.6s to complete
#     error(train)=1.29e-01, acc(train)=9.52e-01, error(valid)=1.53e+00, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 86: 7.9s to complete
#     error(train)=1.16e-01, acc(train)=9.54e-01, error(valid)=1.47e+00, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 87: 7.9s to complete
#     error(train)=1.27e-01, acc(train)=9.53e-01, error(valid)=1.55e+00, acc(valid)=8.20e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 88: 7.7s to complete
#     error(train)=1.13e-01, acc(train)=9.56e-01, error(valid)=1.53e+00, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 89: 8.4s to complete
#     error(train)=1.13e-01, acc(train)=9.56e-01, error(valid)=1.54e+00, acc(valid)=8.19e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 90: 8.2s to complete
#     error(train)=1.18e-01, acc(train)=9.54e-01, error(valid)=1.60e+00, acc(valid)=8.22e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 91: 7.7s to complete
#     error(train)=1.05e-01, acc(train)=9.59e-01, error(valid)=1.58e+00, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 92: 8.1s to complete
#     error(train)=1.37e-01, acc(train)=9.49e-01, error(valid)=1.57e+00, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 93: 7.7s to complete
#     error(train)=1.05e-01, acc(train)=9.60e-01, error(valid)=1.62e+00, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 94: 7.9s to complete
#     error(train)=9.86e-02, acc(train)=9.61e-01, error(valid)=1.57e+00, acc(valid)=8.26e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 95: 8.1s to complete
#     error(train)=1.11e-01, acc(train)=9.56e-01, error(valid)=1.59e+00, acc(valid)=8.25e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 96: 7.9s to complete
#     error(train)=1.05e-01, acc(train)=9.58e-01, error(valid)=1.63e+00, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 97: 7.9s to complete
#     error(train)=1.14e-01, acc(train)=9.57e-01, error(valid)=1.71e+00, acc(valid)=8.21e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 98: 7.7s to complete
#     error(train)=1.10e-01, acc(train)=9.58e-01, error(valid)=1.64e+00, acc(valid)=8.24e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 99: 8.1s to complete
#     error(train)=1.13e-01, acc(train)=9.57e-01, error(valid)=1.67e+00, acc(valid)=8.23e-01
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 100: 7.7s to complete
#     error(train)=1.07e-01, acc(train)=9.58e-01, error(valid)=1.71e+00, acc(valid)=8.24e-01
# OrderedDict([('error(test)', 1.8081311149936687), ('acc(test)', 0.8117088607594934)])

# %% [markdown]
# ## 4.3 Activation Functions Comparisions
